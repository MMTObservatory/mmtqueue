# %% [markdown]
# ##  MeridianConstraint tester1
# Note: uses astropy >= 2.0 and astroplan >= 0.4 and astroplan's FixedTarget.  Numpy is used when possible.

# %%
#!/usr/bin/env python3
"""
MeridianConstraint tester.
"""
# Out:
# '\nMeridianConstraint tester.\n'

# %%
import pkg_resources
pkg_resources.require("astropy>=2.0")
pkg_resources.require("astroplan>=0.4")
# Out:
# [astroplan 0.4 (/Users/jdgibson/anaconda3/lib/python3.6/site-packages),
#  pytz 2017.2 (/Users/jdgibson/anaconda3/lib/python3.6/site-packages),
#  astropy 2.0.2 (/Users/jdgibson/anaconda3/lib/python3.6/site-packages),
#  numpy 1.13.3 (/Users/jdgibson/anaconda3/lib/python3.6/site-packages),
#  numpy 1.13.3 (/Users/jdgibson/anaconda3/lib/python3.6/site-packages),
#  pytest 3.2.1 (/Users/jdgibson/anaconda3/lib/python3.6/site-packages),
#  setuptools 36.5.0.post20170921 (/Users/jdgibson/anaconda3/lib/python3.6/site-packages),
#  py 1.4.34 (/Users/jdgibson/anaconda3/lib/python3.6/site-packages)]

# %%
# from astroplan import download_IERS_A
# download_IERS_A()

# %%
from astroplan import Observer, FixedTarget
from astropy.time import Time, TimeDelta

# %%
from astroplan import Constraint, AtNightConstraint, AirmassConstraint
from astroplan import SequentialScheduler, ObservingBlock
from astroplan.constraints import _get_altaz, is_event_observable
from astropy.coordinates import Angle
from astropy.coordinates import SkyCoord
import astropy.units as u
import numpy as np
import datetime
import requests
import json

# %%
import sqlite3
from sqlite3 import Error

"""
CREATE TABLE `scores` (
	`key`	TEXT,
	`value`	REAL,
	PRIMARY KEY(`key`)
)
"""
sqlite_file = '/Users/jdgibson/git/QueueScheduler2.0/scores.sqlite' 
table = "scores"

# %%
# create a database connection
conn = sqlite3.connect(sqlite_file)

# %%
def get_score(key):
    """

    """
    global conn
    c = conn.cursor()
    c.execute("SELECT * FROM scores WHERE key='{}'".format(key)) 
    row = c.fetchone()
    return row

# %%
def set_score(key, value):
    """

    """
    global conn
    c = conn.cursor()
    
    try:
        sql = "REPLACE INTO scores VALUES ('{}', {})".format(key, value)
        if False:
            print("sql: ", sql)
        
        # Can do this with new versions of sqlite.  It does commits automatically.
        with conn:
            conn.execute(sql)

        # Older version.
        # c.execute(sql)
        # Save (commit) the changes
        # conn.commit()
        # conn.close()
    except sqlite3.IntegrityError:
        print('ERROR: ID already exists in PRIMARY KEY column {}'.format("key"))

# %%
def get_constraint_name(constraint):
    return  type(constraint).__name__

# %%
def is_numeric(s):
    try:
        float(s)
        return True
    except ValueError:
        return False

# %%
def get_key(constraint, target, time):
    """
    
    """
    time.format = 'isot'
    constraint_name = get_constraint_name(constraint)
    key = "{}.{}.{}".format(target, 
                            str(time), 
                            constraint_name)
    if False:
        print("key:", key)
    return key

# %%
def dict_factory(cursor, row):
    d = {}
    for idx,col in enumerate(cursor.description):
        d[col[0]] = row[idx]
    return d

# %%
# schedule_id = 804, December binospec run
queue_id = 804
url = 'https://scheduler.mmto.arizona.edu/QueueSchedules/config_json.php?formatted=0&schedule_id='
url += str(queue_id)
r = requests.get(url)
txt = r.text
txt = txt.replace("<pre>\n","")
txt = txt.replace("</pre>\n","")
txt = txt.replace("\s+","")
txt = txt.replace("\n","")
txt = txt.replace("&amp;&amp;","")

# %%
if False:
    print(txt)

# %%
meta = json.loads(txt)
if True:
    txt = json.dumps(meta, indent=2)
    print(txt)
# Out:
# {
#   "schedule_id": "804",
#   "debug": "False",
#   "verbose": "True",
#   "instrument": "binospec",
#   "queuerun_id": "62",
#   "configuration": {
#     "transit_constrait_mode": {
#       "id": 536,
#       "parametername": "transit_constrait_mode",
#       "parametervalue": 0,
#       "parametertype": "integer",
#       "observingqueuerunid": 62,
#       "notes": null
#     },
#     "use_transit_constraint": {
#       "id": 535,
#       "parametername": "use_transit_constraint",
#       "parametervalue": "false",
#       "parametertype": "boolean",
#       "observingqueuerunid": 62,
#       "notes": null
#     },
#     "max_mask_angle": {
#       "id": 534,
#       "parametername": "max_mask_angle",
#       "parametervalue": 30,
#       "parametertype": "float",
#       "observingqueuerunid": 62,
#       "notes": null
#     },
#     "use_pi_priority_constraint": {
#       "id": 533,
#       "parametername": "use_pi_priority_constraint",
#       "parametervalue": "true",
#       "parametertype": "boolean",
#       "observingqueuerunid": 62,
#       "notes": null
#     },
#     "max_pi_priority": {
#       "id": 532,
#       "parametername": "max_pi_priority",
#       "parametervalue": 1,
#       "parametertype": "integer",
#       "observingqueuerunid": 62,
#       "notes": null
#     },
#     "min_pi_priority": {
#       "id": 531,
#       "parametername": "min_pi_priority",
#       "parametervalue": 999,
#       "parametertype": "integer",
#       "observingqueuerunid": 62,
#       "notes": null
#     },
#     "use_tac_priority_constraint": {
#       "id": 530,
#       "parametername": "use_tac_priority_constraint",
#       "parametervalue": "False",
#       "parametertype": "boolean",
#       "observingqueuerunid": 62,
#       "notes": null
#     },
#     "max_block_length_seconds": {
#       "id": 529,
#       "parametername": "max_block_length_seconds",
#       "parametervalue": 7200,
#       "parametertype": "integer",
#       "observingqueuerunid": 62,
#       "notes": null
#     },
#     "max_fields": {
#       "id": 528,
#       "parametername": "max_fields",
#       "parametervalue": 999,
#       "parametertype": "integer",
#       "observingqueuerunid": 62,
#       "notes": null
#     },
#     "do_mysql": {
#       "id": 527,
#       "parametername": "do_mysql",
#       "parametervalue": "false",
#       "parametertype": "boolean",
#       "observingqueuerunid": 62,
#       "notes": null
#     },
#     "do_plot_parallactic": {
#       "id": 526,
#       "parametername": "do_plot_parallactic",
#       "parametervalue": "false",
#       "parametertype": "boolean",
#       "observingqueuerunid": 62,
#       "notes": null
#     },
#     "time_resolution_seconds": {
#       "id": 525,
#       "parametername": "time_resolution_seconds",
#       "parametervalue": 20,
#       "parametertype": "float",
#       "observingqueuerunid": 62,
#       "notes": null
#     },
#     "imaging_overhead_seconds": {
#       "id": 524,
#       "parametername": "imaging_overhead_seconds",
#       "parametervalue": 300,
#       "parametertype": "float",
#       "observingqueuerunid": 62,
#       "notes": "From 600 (Richard Cool) to 5 min = 300 sec (Igor Chilingarian), 2016-10-19"
#     },
#     "mask_overhead_seconds": {
#       "id": 523,
#       "parametername": "mask_overhead_seconds",
#       "parametervalue": 1800,
#       "parametertype": "float",
#       "observingqueuerunid": 62,
#       "notes": "From 2700 (Richard Cool) to 30 min = 1800 sec (Joannah Hinz), 2016-10-20"
#     },
#     "longslit_overhead_seconds": {
#       "id": 522,
#       "parametername": "longslit_overhead_seconds",
#       "parametervalue": 1800,
#       "parametertype": "float",
#       "observingqueuerunid": 62,
#       "notes": "From 1800 (Richard Cool) to 20 min = 1200 sec (Igor Chilingarian), 2016-10-19"
#     },
#     "gap_time_hours": {
#       "id": 521,
#       "parametername": "gap_time_hours",
#       "parametervalue": 0.5,
#       "parametertype": "float",
#       "observingqueuerunid": 62,
#       "notes": null
#     },
#     "slew_rate": {
#       "id": 520,
#       "parametername": "slew_rate",
#       "parametervalue": 1,
#       "parametertype": "float",
#       "observingqueuerunid": 62,
#       "notes": null
#     },
#     "slew_duration_seconds": {
#       "id": 519,
#       "parametername": "slew_duration_seconds",
#       "parametervalue": 60,
#       "parametertype": "float",
#       "observingqueuerunid": 62,
#       "notes": null
#     },
#     "moon_separation_degrees": {
#       "id": 518,
#       "parametername": "moon_separation_degrees",
#       "parametervalue": 15,
#       "parametertype": "float",
#       "observingqueuerunid": 62,
#       "notes": null
#     },
#     "max_rot_degrees": {
#       "id": 517,
#       "parametername": "max_rot_degrees",
#       "parametervalue": 179,
#       "parametertype": "float",
#       "observingqueuerunid": 62,
#       "notes": "New 160 (emartin oplog 2016-11-11), Old -164"
#     },
#     "min_alt_degrees": {
#       "id": 516,
#       "parametername": "min_alt_degrees",
#       "parametervalue": 20,
#       "parametertype": "float",
#       "observingqueuerunid": 62,
#       "notes": null
#     },
#     "max_alt_degrees": {
#       "id": 515,
#       "parametername": "max_alt_degrees",
#       "parametervalue": 88,
#       "parametertype": "float",
#       "observingqueuerunid": 62,
#       "notes": null
#     },
#     "max_airmass": {
#       "id": 514,
#       "parametername": "max_airmass",
#       "parametervalue": 2.5,
#       "parametertype": "float",
#       "observingqueuerunid": 62,
#       "notes": null
#     },
#     "min_poor_seeing": {
#       "id": 513,
#       "parametername": "min_poor_seeing",
#       "parametervalue": 1.4,
#       "parametertype": "float",
#       "observingqueuerunid": 62,
#       "notes": null
#     },
#     "max_good_seeing": {
#       "id": 512,
#       "parametername": "max_good_seeing",
#       "parametervalue": 1,
#       "parametertype": "float",
#       "observingqueuerunid": 62,
#       "notes": null
#     },
#     "min_seeing": {
#       "id": 511,
#       "parametername": "min_seeing",
#       "parametervalue": 0.1,
#       "parametertype": "float",
#       "observingqueuerunid": 62,
#       "notes": null
#     },
#     "max_seeing": {
#       "id": 510,
#       "parametername": "max_seeing",
#       "parametervalue": 5,
#       "parametertype": "float",
#       "observingqueuerunid": 62,
#       "notes": null
#     },
#     "max_solar_altitude": {
#       "id": 509,
#       "parametername": "max_solar_altitude",
#       "parametervalue": -12,
#       "parametertype": "integer",
#       "observingqueuerunid": 62,
#       "notes": "Civil -6; Nautical, -12, Astronomical, -18"
#     },
#     "use_minimal_constraints": {
#       "id": 508,
#       "parametername": "use_minimal_constraints",
#       "parametervalue": "false",
#       "parametertype": "boolean",
#       "observingqueuerunid": 62,
#       "notes": null
#     },
#     "use_time_allocation_boolean": {
#       "id": 507,
#       "parametername": "use_time_allocation_boolean",
#       "parametervalue": "false",
#       "parametertype": "boolean",
#       "observingqueuerunid": 62,
#       "notes": "Boolean == True, Float == False"
#     },
#     "use_time_allocation_constraint": {
#       "id": 506,
#       "parametername": "use_time_allocation_constraint",
#       "parametervalue": "true",
#       "parametertype": "boolean",
#       "observingqueuerunid": 62,
#       "notes": null
#     },
#     "use_time_constraint": {
#       "id": 505,
#       "parametername": "use_time_constraint",
#       "parametervalue": "true",
#       "parametertype": "boolean",
#       "observingqueuerunid": 62,
#       "notes": null
#     },
#     "use_rotator_constraint": {
#       "id": 504,
#       "parametername": "use_rotator_constraint",
#       "parametervalue": "true",
#       "parametertype": "boolean",
#       "observingqueuerunid": 62,
#       "notes": null
#     },
#     "use_programmatic_constraint": {
#       "id": 503,
#       "parametername": "use_programmatic_constraint",
#       "parametervalue": "false",
#       "parametertype": "boolean",
#       "observingqueuerunid": 62,
#       "notes": null
#     },
#     "use_moon_separation_constraint": {
#       "id": 502,
#       "parametername": "use_moon_separation_constraint",
#       "parametervalue": "true",
#       "parametertype": "boolean",
#       "observingqueuerunid": 62,
#       "notes": null
#     },
#     "use_moon_illumination_constraint": {
#       "id": 501,
#       "parametername": "use_moon_illumination_constraint",
#       "parametervalue": "false",
#       "parametertype": "boolean",
#       "observingqueuerunid": 62,
#       "notes": null
#     },
#     "use_meridian_constraint": {
#       "id": 500,
#       "parametername": "use_meridian_constraint",
#       "parametervalue": "true",
#       "parametertype": "boolean",
#       "observingqueuerunid": 62,
#       "notes": null
#     },
#     "use_at_night_constraint": {
#       "id": 499,
#       "parametername": "use_at_night_constraint",
#       "parametervalue": "true",
#       "parametertype": "boolean",
#       "observingqueuerunid": 62,
#       "notes": null
#     },
#     "use_altitude_boolean": {
#       "id": 498,
#       "parametername": "use_altitude_boolean",
#       "parametervalue": "false",
#       "parametertype": "boolean",
#       "observingqueuerunid": 62,
#       "notes": null
#     },
#     "use_altitude_constraint": {
#       "id": 497,
#       "parametername": "use_altitude_constraint",
#       "parametervalue": "true",
#       "parametertype": "boolean",
#       "observingqueuerunid": 62,
#       "notes": null
#     },
#     "use_airmass_constraint": {
#       "id": 496,
#       "parametername": "use_airmass_constraint",
#       "parametervalue": "true",
#       "parametertype": "boolean",
#       "observingqueuerunid": 62,
#       "notes": null
#     },
#     "trimester": {
#       "id": 495,
#       "parametername": "trimester",
#       "parametervalue": "2017c",
#       "parametertype": "string",
#       "observingqueuerunid": 62,
#       "notes": null
#     },
#     "mode": {
#       "id": 494,
#       "parametername": "mode",
#       "parametervalue": 1,
#       "parametertype": "integer",
#       "observingqueuerunid": 62,
#       "notes": null
#     },
#     "end_date": {
#       "id": 493,
#       "parametername": "end_date",
#       "parametervalue": "2017-12-15 07:00:00",
#       "parametertype": "datetime",
#       "observingqueuerunid": 62,
#       "notes": null
#     },
#     "start_date": {
#       "id": 492,
#       "parametername": "start_date",
#       "parametervalue": "2017-12-14 22:46:00",
#       "parametertype": "datetime",
#       "observingqueuerunid": 62,
#       "notes": null
#     },
#     "use_mask_angle_constraint": {
#       "id": 491,
#       "parametername": "use_mask_angle_constraint",
#       "parametervalue": "true",
#       "parametertype": "boolean",
#       "observingqueuerunid": 62,
#       "notes": null
#     },
#     "min_rot_degrees": {
#       "id": 490,
#       "parametername": "min_rot_degrees",
#       "parametervalue": -166,
#       "parametertype": "float",
#       "observingqueuerunid": 62,
#       "notes": "New -170 (emartin oplog 2016-11-11), Old -180 "
#     }
#   },
#   "allocation": {
#     "374": 5.99,
#     "385": 2.995,
#     "372": 2.995,
#     "380": 35.94,
#     "373": 5.99,
#     "443": 5.99,
#     "444": 11.98,
#     "445": 5.99,
#     "446": 2.995,
#     "447": 2.995,
#     "448": 2.995,
#     "449": 2.995,
#     "450": 2.995,
#     "376": 17.97,
#     "451": 2.995,
#     "452": 2.995,
#     "453": 2.995,
#     "455": 2.995,
#     "456": 2.995
#   },
#   "stats": {
#     "374": {
#       "total_nights_allocated": "0.5",
#       "total_exposure_requested": 21600,
#       "total_exposure_used": 0,
#       "total_overhead_requested": 5400,
#       "total_overhead_used": 0,
#       "program_percent_allocated": 5,
#       "program_hours_allocated": 5.99,
#       "total_hours_requested": 7.5,
#       "total_hours_used": 0,
#       "total_used_percent": 0,
#       "notes": 0
#     },
#     "385": {
#       "total_nights_allocated": "0.25",
#       "total_exposure_requested": 36600,
#       "total_exposure_used": 6480,
#       "total_overhead_requested": 19980,
#       "total_overhead_used": 3180,
#       "program_percent_allocated": 2.5,
#       "program_hours_allocated": 2.995,
#       "total_hours_requested": 15.716666666667,
#       "total_hours_used": 2.6833333333333,
#       "total_used_percent": 89.593767390095,
#       "notes": 0
#     },
#     "372": {
#       "total_nights_allocated": "0.25",
#       "total_exposure_requested": 235,
#       "total_exposure_used": 0,
#       "total_overhead_requested": 7500,
#       "total_overhead_used": 0,
#       "program_percent_allocated": 2.5,
#       "program_hours_allocated": 2.995,
#       "total_hours_requested": 2.1486111111111,
#       "total_hours_used": 0,
#       "total_used_percent": 0,
#       "notes": 0
#     },
#     "380": {
#       "total_nights_allocated": "3",
#       "total_exposure_requested": 115200,
#       "total_exposure_used": 14400,
#       "total_overhead_requested": 110080,
#       "total_overhead_used": 9280,
#       "program_percent_allocated": 30,
#       "program_hours_allocated": 35.94,
#       "total_hours_requested": 62.577777777778,
#       "total_hours_used": 6.5777777777778,
#       "total_used_percent": 18.302108452359,
#       "notes": 0
#     },
#     "373": {
#       "total_nights_allocated": "0.5",
#       "total_exposure_requested": 26400,
#       "total_exposure_used": 0,
#       "total_overhead_requested": 9000,
#       "total_overhead_used": 0,
#       "program_percent_allocated": 5,
#       "program_hours_allocated": 5.99,
#       "total_hours_requested": 9.8333333333333,
#       "total_hours_used": 0,
#       "total_used_percent": 0,
#       "notes": 0
#     },
#     "443": {
#       "total_nights_allocated": "0.5",
#       "total_exposure_requested": 12000,
#       "total_exposure_used": 0,
#       "total_overhead_requested": 3600,
#       "total_overhead_used": 0,
#       "program_percent_allocated": 5,
#       "program_hours_allocated": 5.99,
#       "total_hours_requested": 4.3333333333333,
#       "total_hours_used": 0,
#       "total_used_percent": 0,
#       "notes": 0
#     },
#     "444": {
#       "total_nights_allocated": "1",
#       "total_exposure_requested": 75600,
#       "total_exposure_used": 14400,
#       "total_overhead_requested": 36300,
#       "total_overhead_used": 5700,
#       "program_percent_allocated": 10,
#       "program_hours_allocated": 11.98,
#       "total_hours_requested": 31.083333333333,
#       "total_hours_used": 5.5833333333333,
#       "total_used_percent": 46.605453533667,
#       "notes": 0
#     },
#     "445": {
#       "total_nights_allocated": "0.5",
#       "total_exposure_requested": 28800,
#       "total_exposure_used": 3600,
#       "total_overhead_requested": 14160,
#       "total_overhead_used": 1560,
#       "program_percent_allocated": 5,
#       "program_hours_allocated": 5.99,
#       "total_hours_requested": 11.933333333333,
#       "total_hours_used": 1.4333333333333,
#       "total_used_percent": 23.92877017251,
#       "notes": 0
#     },
#     "446": {
#       "total_nights_allocated": "0.25",
#       "total_exposure_requested": 23850,
#       "total_exposure_used": 0,
#       "total_overhead_requested": 27300,
#       "total_overhead_used": 0,
#       "program_percent_allocated": 2.5,
#       "program_hours_allocated": 2.995,
#       "total_hours_requested": 14.208333333333,
#       "total_hours_used": 0,
#       "total_used_percent": 0,
#       "notes": 0
#     },
#     "447": {
#       "total_nights_allocated": "0.25",
#       "total_exposure_requested": 13200,
#       "total_exposure_used": 0,
#       "total_overhead_requested": 7200,
#       "total_overhead_used": 0,
#       "program_percent_allocated": 2.5,
#       "program_hours_allocated": 2.995,
#       "total_hours_requested": 5.6666666666667,
#       "total_hours_used": 0,
#       "total_used_percent": 0,
#       "notes": 0
#     },
#     "448": {
#       "total_nights_allocated": "0.25",
#       "total_exposure_requested": 28800,
#       "total_exposure_used": 3600,
#       "total_overhead_requested": 7200,
#       "total_overhead_used": 900,
#       "program_percent_allocated": 2.5,
#       "program_hours_allocated": 2.995,
#       "total_hours_requested": 10,
#       "total_hours_used": 1.25,
#       "total_used_percent": 41.736227045075,
#       "notes": 0
#     },
#     "449": {
#       "total_nights_allocated": "0.25",
#       "total_exposure_requested": 10800,
#       "total_exposure_used": 3600,
#       "total_overhead_requested": 4800,
#       "total_overhead_used": 1200,
#       "program_percent_allocated": 2.5,
#       "program_hours_allocated": 2.995,
#       "total_hours_requested": 4.3333333333333,
#       "total_hours_used": 1.3333333333333,
#       "total_used_percent": 44.518642181413,
#       "notes": 0
#     },
#     "450": {
#       "total_nights_allocated": "0.25",
#       "total_exposure_requested": 9600,
#       "total_exposure_used": 480,
#       "total_overhead_requested": 3600,
#       "total_overhead_used": 360,
#       "program_percent_allocated": 2.5,
#       "program_hours_allocated": 2.995,
#       "total_hours_requested": 3.6666666666667,
#       "total_hours_used": 0.23333333333333,
#       "total_used_percent": 7.7907623817474,
#       "notes": 0
#     },
#     "376": {
#       "total_nights_allocated": "1.5",
#       "total_exposure_requested": 54000,
#       "total_exposure_used": 9000,
#       "total_overhead_requested": 21180,
#       "total_overhead_used": 3180,
#       "program_percent_allocated": 15,
#       "program_hours_allocated": 17.97,
#       "total_hours_requested": 20.883333333333,
#       "total_hours_used": 3.3833333333333,
#       "total_used_percent": 18.827675755889,
#       "notes": 0
#     },
#     "451": {
#       "total_nights_allocated": "0.25",
#       "total_exposure_requested": 11160,
#       "total_exposure_used": 0,
#       "total_overhead_requested": 55800,
#       "total_overhead_used": 0,
#       "program_percent_allocated": 2.5,
#       "program_hours_allocated": 2.995,
#       "total_hours_requested": 18.6,
#       "total_hours_used": 0,
#       "total_used_percent": 0,
#       "notes": 0
#     },
#     "452": {
#       "total_nights_allocated": "0.25",
#       "total_exposure_requested": 13440,
#       "total_exposure_used": 0,
#       "total_overhead_requested": 12600,
#       "total_overhead_used": 0,
#       "program_percent_allocated": 2.5,
#       "program_hours_allocated": 2.995,
#       "total_hours_requested": 7.2333333333333,
#       "total_hours_used": 0,
#       "total_used_percent": 0,
#       "notes": 0
#     },
#     "453": {
#       "total_nights_allocated": "0.25",
#       "total_exposure_requested": 10800,
#       "total_exposure_used": 0,
#       "total_overhead_requested": 3600,
#       "total_overhead_used": 0,
#       "program_percent_allocated": 2.5,
#       "program_hours_allocated": 2.995,
#       "total_hours_requested": 4,
#       "total_hours_used": 0,
#       "total_used_percent": 0,
#       "notes": 0
#     },
#     "455": {
#       "total_nights_allocated": "0.25",
#       "total_exposure_requested": 13500,
#       "total_exposure_used": 0,
#       "total_overhead_requested": 14400,
#       "total_overhead_used": 0,
#       "program_percent_allocated": 2.5,
#       "program_hours_allocated": 2.995,
#       "total_hours_requested": 7.75,
#       "total_hours_used": 0,
#       "total_used_percent": 0,
#       "notes": 0
#     },
#     "456": {
#       "total_nights_allocated": "0.25",
#       "total_exposure_requested": 43200,
#       "total_exposure_used": 0,
#       "total_overhead_requested": 10800,
#       "total_overhead_used": 0,
#       "program_percent_allocated": 2.5,
#       "program_hours_allocated": 2.995,
#       "total_hours_requested": 15,
#       "total_hours_used": 0,
#       "total_used_percent": 0,
#       "notes": 0
#     }
#   },
#   "fields": [
#     {
#       "block_id": "7993",
#       "objid_id": "1128",
#       "objid": "AT2017hyo",
#       "complete": "False",
#       "ra_hms": "01h21m35.36s",
#       "dec_dms": "+03d17m40.66s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "Blanchard",
#       "program": "385",
#       "program_id": "SAO-14",
#       "tac_priority": 2,
#       "pi_priority": "1",
#       "max_seeing": null,
#       "duration": "2700",
#       "overhead": "1800",
#       "objtype": "longslit",
#       "mask_id": "111",
#       "mask": "Longslit1",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7752",
#       "objid_id": "801",
#       "objid": "PS16aqy (copy)",
#       "complete": "False",
#       "ra_hms": "10h19m02.17s",
#       "dec_dms": "+74d42m24.6s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "Blanchard",
#       "program": "385",
#       "program_id": "SAO-14",
#       "tac_priority": 2,
#       "pi_priority": "1",
#       "max_seeing": null,
#       "duration": "3600",
#       "overhead": "1800",
#       "objtype": "longslit",
#       "mask_id": "111",
#       "mask": "Longslit1",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "8004",
#       "objid_id": "1137",
#       "objid": "AT2017hyo",
#       "complete": "False",
#       "ra_hms": "01h21m35.36s",
#       "dec_dms": "+03d17m40.66s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "Blanchard",
#       "program": "385",
#       "program_id": "SAO-14",
#       "tac_priority": 2,
#       "pi_priority": "1",
#       "max_seeing": null,
#       "duration": "180",
#       "overhead": "300",
#       "objtype": "imaging",
#       "mask_id": "110",
#       "mask": "",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7749",
#       "objid_id": "799",
#       "objid": "PS16aqy (copy)",
#       "complete": "False",
#       "ra_hms": "10h19m02.18s",
#       "dec_dms": "+74d42m24.6s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "Blanchard",
#       "program": "385",
#       "program_id": "SAO-14",
#       "tac_priority": 2,
#       "pi_priority": "1",
#       "max_seeing": null,
#       "duration": "1800",
#       "overhead": "300",
#       "objtype": "imaging",
#       "mask_id": "110",
#       "mask": "",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7999",
#       "objid_id": "1138",
#       "objid": "AT2017hyo",
#       "complete": "False",
#       "ra_hms": "01h21m35.36s",
#       "dec_dms": "+03d17m40.66s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "Blanchard",
#       "program": "385",
#       "program_id": "SAO-14",
#       "tac_priority": 2,
#       "pi_priority": "1",
#       "max_seeing": null,
#       "duration": "180",
#       "overhead": "300",
#       "objtype": "imaging",
#       "mask_id": "110",
#       "mask": "",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "8000",
#       "objid_id": "1139",
#       "objid": "AT2017hyo",
#       "complete": "False",
#       "ra_hms": "01h21m35.36s",
#       "dec_dms": "+03d17m40.66s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "Blanchard",
#       "program": "385",
#       "program_id": "SAO-14",
#       "tac_priority": 2,
#       "pi_priority": "1",
#       "max_seeing": null,
#       "duration": "180",
#       "overhead": "300",
#       "objtype": "imaging",
#       "mask_id": "110",
#       "mask": "",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "8001",
#       "objid_id": "1140",
#       "objid": "PS17dbf",
#       "complete": "False",
#       "ra_hms": "14h34m42.92s",
#       "dec_dms": "+31d29m16.7s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "Blanchard",
#       "program": "385",
#       "program_id": "SAO-14",
#       "tac_priority": 2,
#       "pi_priority": "1",
#       "max_seeing": null,
#       "duration": "900",
#       "overhead": "300",
#       "objtype": "imaging",
#       "mask_id": "110",
#       "mask": "",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7753",
#       "objid_id": "797",
#       "objid": "PS16fgt (copy)",
#       "complete": "False",
#       "ra_hms": "02h44m25.82s",
#       "dec_dms": "+19d10m42.6s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "Blanchard",
#       "program": "385",
#       "program_id": "SAO-14",
#       "tac_priority": 2,
#       "pi_priority": "1",
#       "max_seeing": null,
#       "duration": "900",
#       "overhead": "300",
#       "objtype": "imaging",
#       "mask_id": "110",
#       "mask": "",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7751",
#       "objid_id": "800",
#       "objid": "PS16fgt (copy)",
#       "complete": "False",
#       "ra_hms": "02h44m25.82s",
#       "dec_dms": "+19d10m42.6s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "Blanchard",
#       "program": "385",
#       "program_id": "SAO-14",
#       "tac_priority": 2,
#       "pi_priority": "2",
#       "max_seeing": null,
#       "duration": "5400",
#       "overhead": "1800",
#       "objtype": "longslit",
#       "mask_id": "111",
#       "mask": "Longslit1",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7760",
#       "objid_id": "804",
#       "objid": "Gaia16bvd (copy)",
#       "complete": "False",
#       "ra_hms": "12h32m33.23s",
#       "dec_dms": "+27d07m15.4s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "Blanchard",
#       "program": "385",
#       "program_id": "SAO-14",
#       "tac_priority": 2,
#       "pi_priority": "2",
#       "max_seeing": null,
#       "duration": "1800",
#       "overhead": "1800",
#       "objtype": "longslit",
#       "mask_id": "111",
#       "mask": "Longslit1",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7756",
#       "objid_id": "803",
#       "objid": "PS16fgt  (copy)",
#       "complete": "False",
#       "ra_hms": "02h44m25.82s",
#       "dec_dms": "+19d10m42.6s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "Blanchard",
#       "program": "385",
#       "program_id": "SAO-14",
#       "tac_priority": 2,
#       "pi_priority": "2",
#       "max_seeing": null,
#       "duration": "1080",
#       "overhead": "300",
#       "objtype": "imaging",
#       "mask_id": "110",
#       "mask": "",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7750",
#       "objid_id": "798",
#       "objid": "PS16fgt (copy)",
#       "complete": "False",
#       "ra_hms": "02h44m25.82s",
#       "dec_dms": "+19d10m42.6s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "Blanchard",
#       "program": "385",
#       "program_id": "SAO-14",
#       "tac_priority": 2,
#       "pi_priority": "2",
#       "max_seeing": null,
#       "duration": "960",
#       "overhead": "300",
#       "objtype": "imaging",
#       "mask_id": "110",
#       "mask": "",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7759",
#       "objid_id": "802",
#       "objid": "SN2017egm (copy)",
#       "complete": "False",
#       "ra_hms": "10h19m05.62s",
#       "dec_dms": "+46d27m14.08s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "Blanchard",
#       "program": "385",
#       "program_id": "SAO-14",
#       "tac_priority": 2,
#       "pi_priority": "2",
#       "max_seeing": null,
#       "duration": "300",
#       "overhead": "1800",
#       "objtype": "longslit",
#       "mask_id": "111",
#       "mask": "Longslit1",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7755",
#       "objid_id": "806",
#       "objid": "PS17dqb (copy)",
#       "complete": "False",
#       "ra_hms": "21h35m15.26s",
#       "dec_dms": "-06d58m28.3s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "Blanchard",
#       "program": "385",
#       "program_id": "SAO-14",
#       "tac_priority": 2,
#       "pi_priority": "3",
#       "max_seeing": null,
#       "duration": "3600",
#       "overhead": "1800",
#       "objtype": "longslit",
#       "mask_id": "111",
#       "mask": "Longslit1",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7757",
#       "objid_id": "807",
#       "objid": "PS17dqb (copy)",
#       "complete": "False",
#       "ra_hms": "21h35m15.26s",
#       "dec_dms": "-06d58m28.3s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "Blanchard",
#       "program": "385",
#       "program_id": "SAO-14",
#       "tac_priority": 2,
#       "pi_priority": "3",
#       "max_seeing": null,
#       "duration": "300",
#       "overhead": "300",
#       "objtype": "imaging",
#       "mask_id": "110",
#       "mask": "",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7764",
#       "objid_id": "809",
#       "objid": "PS17dqb (copy)",
#       "complete": "False",
#       "ra_hms": "21h35m15.26s",
#       "dec_dms": "-06d58m28.3s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "Blanchard",
#       "program": "385",
#       "program_id": "SAO-14",
#       "tac_priority": 2,
#       "pi_priority": "3",
#       "max_seeing": null,
#       "duration": "360",
#       "overhead": "300",
#       "objtype": "imaging",
#       "mask_id": "110",
#       "mask": "",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7758",
#       "objid_id": "808",
#       "objid": "PS16fgt (copy)",
#       "complete": "False",
#       "ra_hms": "02h44m25.82s",
#       "dec_dms": "+19d10m42.6s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "Blanchard",
#       "program": "385",
#       "program_id": "SAO-14",
#       "tac_priority": 2,
#       "pi_priority": "3",
#       "max_seeing": null,
#       "duration": "900",
#       "overhead": "300",
#       "objtype": "imaging",
#       "mask_id": "110",
#       "mask": "",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7763",
#       "objid_id": "811",
#       "objid": "PS17dqb (copy)",
#       "complete": "False",
#       "ra_hms": "21h35m15.26s",
#       "dec_dms": "-06d58m28.3s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "Blanchard",
#       "program": "385",
#       "program_id": "SAO-14",
#       "tac_priority": 2,
#       "pi_priority": "3",
#       "max_seeing": null,
#       "duration": "240",
#       "overhead": "300",
#       "objtype": "imaging",
#       "mask_id": "110",
#       "mask": "",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "8005",
#       "objid_id": "1127",
#       "objid": "PS17brq",
#       "complete": "False",
#       "ra_hms": "12h32m33.23s",
#       "dec_dms": "+27d07m15.49s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "Blanchard",
#       "program": "385",
#       "program_id": "SAO-14",
#       "tac_priority": 2,
#       "pi_priority": "3",
#       "max_seeing": null,
#       "duration": "300",
#       "overhead": "300",
#       "objtype": "imaging",
#       "mask_id": "110",
#       "mask": "",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7765",
#       "objid_id": "812",
#       "objid": "PS17dqb (copy)",
#       "complete": "False",
#       "ra_hms": "21h35m15.26s",
#       "dec_dms": "-06d58m28.3s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "Blanchard",
#       "program": "385",
#       "program_id": "SAO-14",
#       "tac_priority": 2,
#       "pi_priority": "3",
#       "max_seeing": null,
#       "duration": "180",
#       "overhead": "300",
#       "objtype": "imaging",
#       "mask_id": "110",
#       "mask": "",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7754",
#       "objid_id": "805",
#       "objid": "Gaia16apd (copy)",
#       "complete": "False",
#       "ra_hms": "12h02m51.71s",
#       "dec_dms": "+44d15m27.4s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "Blanchard",
#       "program": "385",
#       "program_id": "SAO-14",
#       "tac_priority": 2,
#       "pi_priority": "3",
#       "max_seeing": null,
#       "duration": "2700",
#       "overhead": "1800",
#       "objtype": "longslit",
#       "mask_id": "111",
#       "mask": "Longslit1",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7766",
#       "objid_id": "796",
#       "objid": "NGC2419 (copy)",
#       "complete": "False",
#       "ra_hms": "07h38m29.63s",
#       "dec_dms": "+38d47m14.72s",
#       "epoch": "J2000",
#       "posang": "90",
#       "moon": null,
#       "pi": "Fabricant",
#       "program": "372",
#       "program_id": "SAO-1",
#       "tac_priority": 2,
#       "pi_priority": "1",
#       "max_seeing": null,
#       "duration": "15",
#       "overhead": "300",
#       "objtype": "imaging",
#       "mask_id": "110",
#       "mask": "",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7864",
#       "objid_id": "818",
#       "objid": "Zahid_COSMOS4",
#       "complete": "False",
#       "ra_hms": "10h00m57.180s",
#       "dec_dms": "+2d13m53.430s",
#       "epoch": "J2000",
#       "posang": "-56",
#       "moon": null,
#       "pi": "Zahid",
#       "program": "445",
#       "program_id": "SAO-1C",
#       "tac_priority": 2,
#       "pi_priority": "1",
#       "max_seeing": null,
#       "duration": "3600",
#       "overhead": "1800",
#       "objtype": "mask",
#       "mask_id": "136",
#       "design_parang": "-35.6777",
#       "mask": "",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7865",
#       "objid_id": "817",
#       "objid": "Zahid_COSMOS3",
#       "complete": "False",
#       "ra_hms": "10h02m14.326s",
#       "dec_dms": "+2d12m49.470s",
#       "epoch": "J2000",
#       "posang": "-59",
#       "moon": null,
#       "pi": "Zahid",
#       "program": "445",
#       "program_id": "SAO-1C",
#       "tac_priority": 2,
#       "pi_priority": "1",
#       "max_seeing": null,
#       "duration": "3600",
#       "overhead": "1800",
#       "objtype": "mask",
#       "mask_id": "135",
#       "design_parang": "-35.9895",
#       "mask": "",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7866",
#       "objid_id": "816",
#       "objid": "Zahid_COSMOS2",
#       "complete": "False",
#       "ra_hms": "9h59m34.435s",
#       "dec_dms": "+2d31m36.850s",
#       "epoch": "J2000",
#       "posang": "-17",
#       "moon": null,
#       "pi": "Zahid",
#       "program": "445",
#       "program_id": "SAO-1C",
#       "tac_priority": 2,
#       "pi_priority": "1",
#       "max_seeing": null,
#       "duration": "3600",
#       "overhead": "1800",
#       "objtype": "mask",
#       "mask_id": "134",
#       "design_parang": "-35.5506",
#       "mask": "",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7881",
#       "objid_id": "835",
#       "objid": "SAO-9_04016+2610 (copy)",
#       "complete": "False",
#       "ra_hms": "04h04m43.22s",
#       "dec_dms": "+26d18m54.5s",
#       "epoch": "J2000.0",
#       "posang": "30",
#       "moon": "bright",
#       "pi": "Kenyon",
#       "program": "446",
#       "program_id": "SAO-1D",
#       "tac_priority": 2,
#       "pi_priority": "1",
#       "max_seeing": "3",
#       "duration": "360",
#       "overhead": "1800",
#       "objtype": "longslit",
#       "mask_id": "111",
#       "mask": "Longslit1long",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7873",
#       "objid_id": "823",
#       "objid": "SAO-9_04295+2251 (copy)",
#       "complete": "False",
#       "ra_hms": "04h32m32.05s",
#       "dec_dms": "+22d57m26.6s",
#       "epoch": "J2000.0",
#       "posang": "68",
#       "moon": "bright",
#       "pi": "Kenyon",
#       "program": "446",
#       "program_id": "SAO-1D",
#       "tac_priority": 2,
#       "pi_priority": "1",
#       "max_seeing": "3",
#       "duration": "900",
#       "overhead": "1800",
#       "objtype": "longslit",
#       "mask_id": "111",
#       "mask": "Longslit1long",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7871",
#       "objid_id": "822",
#       "objid": "SAO-9_04264+2433 (copy)",
#       "complete": "False",
#       "ra_hms": "04h29m30.08s",
#       "dec_dms": "+24d39m55.0s",
#       "epoch": "J2000.0",
#       "posang": "17",
#       "moon": "bright",
#       "pi": "Kenyon",
#       "program": "446",
#       "program_id": "SAO-1D",
#       "tac_priority": 2,
#       "pi_priority": "1",
#       "max_seeing": "3",
#       "duration": "1200",
#       "overhead": "1800",
#       "objtype": "longslit",
#       "mask_id": "111",
#       "mask": "Longslit1long",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7874",
#       "objid_id": "825",
#       "objid": "SAO-9_L1527IRS (copy)",
#       "complete": "False",
#       "ra_hms": "04h39m53.9s",
#       "dec_dms": "+26d03m11s",
#       "epoch": "J2000.0",
#       "posang": "0",
#       "moon": "bright",
#       "pi": "Kenyon",
#       "program": "446",
#       "program_id": "SAO-1D",
#       "tac_priority": 2,
#       "pi_priority": "1",
#       "max_seeing": "3",
#       "duration": "2700",
#       "overhead": "300",
#       "objtype": "imaging",
#       "mask_id": "110",
#       "mask": "",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7885",
#       "objid_id": "836",
#       "objid": "SAO-9_LkHa358 (copy)",
#       "complete": "False",
#       "ra_hms": "04h31m36.13s",
#       "dec_dms": "+18d13m43.2s",
#       "epoch": "J2000.0",
#       "posang": "45",
#       "moon": "bright",
#       "pi": "Kenyon",
#       "program": "446",
#       "program_id": "SAO-1D",
#       "tac_priority": 2,
#       "pi_priority": "2",
#       "max_seeing": "3",
#       "duration": "360",
#       "overhead": "1800",
#       "objtype": "longslit",
#       "mask_id": "111",
#       "mask": "Longslit1long",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7897",
#       "objid_id": "854",
#       "objid": "SAO-9_04361+2547 (copy)",
#       "complete": "False",
#       "ra_hms": "04h39m13.89s",
#       "dec_dms": "+25d53m20.8s",
#       "epoch": "J2000.0",
#       "posang": "76",
#       "moon": "bright",
#       "pi": "Kenyon",
#       "program": "446",
#       "program_id": "SAO-1D",
#       "tac_priority": 2,
#       "pi_priority": "2",
#       "max_seeing": "3",
#       "duration": "1500",
#       "overhead": "1800",
#       "objtype": "longslit",
#       "mask_id": "111",
#       "mask": "Longslit1long",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7895",
#       "objid_id": "845",
#       "objid": "SAO-9_CoKuTau1 (copy)",
#       "complete": "False",
#       "ra_hms": "04h18m51.47s",
#       "dec_dms": "+28d20m26s",
#       "epoch": "J2000.0",
#       "posang": "90",
#       "moon": "bright",
#       "pi": "Kenyon",
#       "program": "446",
#       "program_id": "SAO-1D",
#       "tac_priority": 2,
#       "pi_priority": "2",
#       "max_seeing": "3",
#       "duration": "1500",
#       "overhead": "1800",
#       "objtype": "longslit",
#       "mask_id": "111",
#       "mask": "Longslit1long",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7886",
#       "objid_id": "846",
#       "objid": "SAO-9_L1551NE (copy)",
#       "complete": "False",
#       "ra_hms": "04h31m44.44s",
#       "dec_dms": "+18d08m31.5s",
#       "epoch": "J2000.0",
#       "posang": "140",
#       "moon": "bright",
#       "pi": "Kenyon",
#       "program": "446",
#       "program_id": "SAO-1D",
#       "tac_priority": 2,
#       "pi_priority": "2",
#       "max_seeing": "3",
#       "duration": "1500",
#       "overhead": "1800",
#       "objtype": "longslit",
#       "mask_id": "111",
#       "mask": "Longslit1long",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7887",
#       "objid_id": "844",
#       "objid": "SAO-9_04489+3042 (copy)",
#       "complete": "False",
#       "ra_hms": "04h52m06.68s",
#       "dec_dms": "+30d47m17.5s",
#       "epoch": "J2000.0",
#       "posang": "51",
#       "moon": "bright",
#       "pi": "Kenyon",
#       "program": "446",
#       "program_id": "SAO-1D",
#       "tac_priority": 2,
#       "pi_priority": "3",
#       "max_seeing": "3",
#       "duration": "900",
#       "overhead": "1800",
#       "objtype": "longslit",
#       "mask_id": "111",
#       "mask": "Longslit1long",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7891",
#       "objid_id": "837",
#       "objid": "SAO-9_04239+2436 (copy)",
#       "complete": "False",
#       "ra_hms": "04h26m56.29s",
#       "dec_dms": "+24d43m35.3s",
#       "epoch": "J2000.0",
#       "posang": "149",
#       "moon": "bright",
#       "pi": "Kenyon",
#       "program": "446",
#       "program_id": "SAO-1D",
#       "tac_priority": 2,
#       "pi_priority": "3",
#       "max_seeing": "3",
#       "duration": "900",
#       "overhead": "1800",
#       "objtype": "longslit",
#       "mask_id": "111",
#       "mask": "Longslit1long",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7890",
#       "objid_id": "838",
#       "objid": "SAO-9_04248+2612 (copy)",
#       "complete": "False",
#       "ra_hms": "04h27m57.30s",
#       "dec_dms": "+26d19m18.3s",
#       "epoch": "J2000.0",
#       "posang": "56",
#       "moon": "bright",
#       "pi": "Kenyon",
#       "program": "446",
#       "program_id": "SAO-1D",
#       "tac_priority": 2,
#       "pi_priority": "3",
#       "max_seeing": "3",
#       "duration": "1500",
#       "overhead": "1800",
#       "objtype": "longslit",
#       "mask_id": "111",
#       "mask": "Longslit1long",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7888",
#       "objid_id": "839",
#       "objid": "SAO-9_04381+2540 (copy)",
#       "complete": "False",
#       "ra_hms": "04h41m12.67s",
#       "dec_dms": "+25d46m35.4s",
#       "epoch": "J2000.0",
#       "posang": "86",
#       "moon": "bright",
#       "pi": "Kenyon",
#       "program": "446",
#       "program_id": "SAO-1D",
#       "tac_priority": 2,
#       "pi_priority": "3",
#       "max_seeing": "3",
#       "duration": "1800",
#       "overhead": "1800",
#       "objtype": "longslit",
#       "mask_id": "111",
#       "mask": "Longslit1long",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7902",
#       "objid_id": "853",
#       "objid": "SAO-9_04365+2535 (copy)",
#       "complete": "False",
#       "ra_hms": "04h39m35.19s",
#       "dec_dms": "+25d41m44.7s",
#       "epoch": "J2000.0",
#       "posang": "82",
#       "moon": "bright",
#       "pi": "Kenyon",
#       "program": "446",
#       "program_id": "SAO-1D",
#       "tac_priority": 2,
#       "pi_priority": "4",
#       "max_seeing": "2",
#       "duration": "1500",
#       "overhead": "1800",
#       "objtype": "longslit",
#       "mask_id": "111",
#       "mask": "Longslit1long",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7900",
#       "objid_id": "848",
#       "objid": "SAO-9_04325+2402 (copy)",
#       "complete": "False",
#       "ra_hms": "04h35m35.39s",
#       "dec_dms": "+24d08m19.4s",
#       "epoch": "J2000.0",
#       "posang": "109",
#       "moon": "bright",
#       "pi": "Kenyon",
#       "program": "446",
#       "program_id": "SAO-1D",
#       "tac_priority": 2,
#       "pi_priority": "4",
#       "max_seeing": "2",
#       "duration": "1500",
#       "overhead": "1800",
#       "objtype": "longslit",
#       "mask_id": "111",
#       "mask": "Longslit1long",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7899",
#       "objid_id": "849",
#       "objid": "SAO-9_04302+2247 (copy)",
#       "complete": "False",
#       "ra_hms": "04h33m16.50s",
#       "dec_dms": "+22d53m20.4s",
#       "epoch": "J2000.0",
#       "posang": "178",
#       "moon": "bright",
#       "pi": "Kenyon",
#       "program": "446",
#       "program_id": "SAO-1D",
#       "tac_priority": 2,
#       "pi_priority": "4",
#       "max_seeing": "3",
#       "duration": "1500",
#       "overhead": "1800",
#       "objtype": "longslit",
#       "mask_id": "111",
#       "mask": "Longslit1long",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7903",
#       "objid_id": "850",
#       "objid": "SAO-9_04301+2608 (copy)",
#       "complete": "False",
#       "ra_hms": "04h33m14.36s",
#       "dec_dms": "+26d14m23.5s",
#       "epoch": "J2000.0",
#       "posang": "0",
#       "moon": "bright",
#       "pi": "Kenyon",
#       "program": "446",
#       "program_id": "SAO-1D",
#       "tac_priority": 2,
#       "pi_priority": "4",
#       "max_seeing": "3",
#       "duration": "1800",
#       "overhead": "1800",
#       "objtype": "longslit",
#       "mask_id": "111",
#       "mask": "Longslit1long",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7905",
#       "objid_id": "899",
#       "objid": "jj0151-2",
#       "complete": "False",
#       "ra_hms": "1h51m20.67s",
#       "dec_dms": "+18d12m47.96s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "Brown",
#       "program": "447",
#       "program_id": "SAO-1E",
#       "tac_priority": 2,
#       "pi_priority": "1",
#       "max_seeing": null,
#       "duration": "1200",
#       "overhead": "1800",
#       "objtype": "longslit",
#       "mask_id": "111",
#       "mask": "Longslit1",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7904",
#       "objid_id": "899",
#       "objid": "jj0151-1",
#       "complete": "False",
#       "ra_hms": "1h51m20.67s",
#       "dec_dms": "+18d12m47.96s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "Brown",
#       "program": "447",
#       "program_id": "SAO-1E",
#       "tac_priority": 2,
#       "pi_priority": "1",
#       "max_seeing": null,
#       "duration": "7200",
#       "overhead": "1800",
#       "objtype": "longslit",
#       "mask_id": "111",
#       "mask": "Longslit1",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7906",
#       "objid_id": "901",
#       "objid": "j0900m",
#       "complete": "False",
#       "ra_hms": "9h00m51.516s",
#       "dec_dms": "-04d42m49.18s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "Brown",
#       "program": "447",
#       "program_id": "SAO-1E",
#       "tac_priority": 2,
#       "pi_priority": "2",
#       "max_seeing": null,
#       "duration": "2400",
# ...
#       "mask_id": "194",
#       "design_parang": "29.4788",
#       "mask": "",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7915",
#       "objid_id": "918",
#       "objid": "UDS-1",
#       "complete": "False",
#       "ra_hms": "2h17m28.331s",
#       "dec_dms": "-5d12m14.460s",
#       "epoch": "J2000",
#       "posang": "-152",
#       "moon": null,
#       "pi": "Tacchella",
#       "program": "450",
#       "program_id": "SAO-1H",
#       "tac_priority": 2,
#       "pi_priority": "1",
#       "max_seeing": null,
#       "duration": "7200",
#       "overhead": "1800",
#       "objtype": "mask",
#       "mask_id": "194",
#       "design_parang": "29.4788",
#       "mask": "",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7982",
#       "objid_id": "1117",
#       "objid": "stream_tri_03",
#       "complete": "False",
#       "ra_hms": "1h24m00.218s",
#       "dec_dms": "+36d24m21.572s",
#       "epoch": "J2000",
#       "posang": "146",
#       "moon": null,
#       "pi": "Bonaca",
#       "program": "376",
#       "program_id": "SAO-5",
#       "tac_priority": 2,
#       "pi_priority": "1",
#       "max_seeing": null,
#       "duration": "4500",
#       "overhead": "1800",
#       "objtype": "mask",
#       "mask_id": "234",
#       "design_parang": "97.1788",
#       "mask": "",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7948",
#       "objid_id": "898",
#       "objid": "Graur_06_TDE2",
#       "complete": "False",
#       "ra_hms": "23h23m48.72s",
#       "dec_dms": "-01d08m10.284s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "Graur",
#       "program": "452",
#       "program_id": "SAO-1K",
#       "tac_priority": 2,
#       "pi_priority": "1",
#       "max_seeing": null,
#       "duration": "1800",
#       "overhead": "1800",
#       "objtype": "longslit",
#       "mask_id": "111",
#       "mask": "Longslit1",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7949",
#       "objid_id": "906",
#       "objid": "Graur_02_PS1-11af",
#       "complete": "False",
#       "ra_hms": "09h57m26.82s",
#       "dec_dms": "+03d14m00.94s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "Graur",
#       "program": "452",
#       "program_id": "SAO-1K",
#       "tac_priority": 2,
#       "pi_priority": "1",
#       "max_seeing": null,
#       "duration": "1800",
#       "overhead": "1800",
#       "objtype": "longslit",
#       "mask_id": "111",
#       "mask": "Longslit1",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7950",
#       "objid_id": "905",
#       "objid": "Graur_02_PS1-11af",
#       "complete": "False",
#       "ra_hms": "09h57m26.82s",
#       "dec_dms": "+03d14m00.94s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "Graur",
#       "program": "452",
#       "program_id": "SAO-1K",
#       "tac_priority": 2,
#       "pi_priority": "1",
#       "max_seeing": null,
#       "duration": "450",
#       "overhead": "300",
#       "objtype": "imaging",
#       "mask_id": "110",
#       "mask": "",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7951",
#       "objid_id": "904",
#       "objid": "Graur_01_SDSSJ0159",
#       "complete": "False",
#       "ra_hms": "01h59m57.64s",
#       "dec_dms": "+00d33m10.49s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "Graur",
#       "program": "452",
#       "program_id": "SAO-1K",
#       "tac_priority": 2,
#       "pi_priority": "1",
#       "max_seeing": null,
#       "duration": "450",
#       "overhead": "300",
#       "objtype": "imaging",
#       "mask_id": "110",
#       "mask": "",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7952",
#       "objid_id": "912",
#       "objid": "Graur_05_D1-9",
#       "complete": "False",
#       "ra_hms": "02h25m17.00s",
#       "dec_dms": "-04d32m59.00s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "Graur",
#       "program": "452",
#       "program_id": "SAO-1K",
#       "tac_priority": 2,
#       "pi_priority": "1",
#       "max_seeing": null,
#       "duration": "1800",
#       "overhead": "1800",
#       "objtype": "longslit",
#       "mask_id": "111",
#       "mask": "Longslit1",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7953",
#       "objid_id": "910",
#       "objid": "Graur_04_2MASXJ0249",
#       "complete": "False",
#       "ra_hms": "02h49m17.31s",
#       "dec_dms": "-04d12m52.1s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "Graur",
#       "program": "452",
#       "program_id": "SAO-1K",
#       "tac_priority": 2,
#       "pi_priority": "1",
#       "max_seeing": null,
#       "duration": "1800",
#       "overhead": "1800",
#       "objtype": "longslit",
#       "mask_id": "111",
#       "mask": "Longslit1",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7954",
#       "objid_id": "908",
#       "objid": "Graur_03_SDSSJ0952",
#       "complete": "False",
#       "ra_hms": "09h52m09.56s",
#       "dec_dms": "+21d43m13.24s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "Graur",
#       "program": "452",
#       "program_id": "SAO-1K",
#       "tac_priority": 2,
#       "pi_priority": "1",
#       "max_seeing": null,
#       "duration": "1800",
#       "overhead": "1800",
#       "objtype": "longslit",
#       "mask_id": "111",
#       "mask": "Longslit1",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7955",
#       "objid_id": "907",
#       "objid": "Graur_03_SDSSJ0952",
#       "complete": "False",
#       "ra_hms": "09h52m09.56s",
#       "dec_dms": "+21d43m13.24s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "Graur",
#       "program": "452",
#       "program_id": "SAO-1K",
#       "tac_priority": 2,
#       "pi_priority": "1",
#       "max_seeing": null,
#       "duration": "420",
#       "overhead": "300",
#       "objtype": "imaging",
#       "mask_id": "110",
#       "mask": "",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7956",
#       "objid_id": "911",
#       "objid": "Graur_05_D1-9",
#       "complete": "False",
#       "ra_hms": "02h25m17.00s",
#       "dec_dms": "-04d32m59.00s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "Graur",
#       "program": "452",
#       "program_id": "SAO-1K",
#       "tac_priority": 2,
#       "pi_priority": "2",
#       "max_seeing": null,
#       "duration": "450",
#       "overhead": "300",
#       "objtype": "imaging",
#       "mask_id": "110",
#       "mask": "",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7957",
#       "objid_id": "902",
#       "objid": "Graur_06_TDE2",
#       "complete": "False",
#       "ra_hms": "23h23m48.72s",
#       "dec_dms": "-01d08m10.284s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "Graur",
#       "program": "452",
#       "program_id": "SAO-1K",
#       "tac_priority": 2,
#       "pi_priority": "2",
#       "max_seeing": null,
#       "duration": "450",
#       "overhead": "300",
#       "objtype": "imaging",
#       "mask_id": "110",
#       "mask": "",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7958",
#       "objid_id": "903",
#       "objid": "Graur_01_SDSSJ0159",
#       "complete": "False",
#       "ra_hms": "01h59m57.64s",
#       "dec_dms": "+00d33m10.49s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "Graur",
#       "program": "452",
#       "program_id": "SAO-1K",
#       "tac_priority": 2,
#       "pi_priority": "3",
#       "max_seeing": null,
#       "duration": "1800",
#       "overhead": "1800",
#       "objtype": "longslit",
#       "mask_id": "111",
#       "mask": "Longslit1",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7959",
#       "objid_id": "909",
#       "objid": "Graur_04_2MASXJ0249",
#       "complete": "False",
#       "ra_hms": "02h49m17.31s",
#       "dec_dms": "-04d12m52.1s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "Graur",
#       "program": "452",
#       "program_id": "SAO-1K",
#       "tac_priority": 2,
#       "pi_priority": "3",
#       "max_seeing": null,
#       "duration": "420",
#       "overhead": "300",
#       "objtype": "imaging",
#       "mask_id": "110",
#       "mask": "",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7963",
#       "objid_id": "913",
#       "objid": "J1029+6115-2",
#       "complete": "False",
#       "ra_hms": "10h29m27.53s",
#       "dec_dms": "+61d15m05.3s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "Oldham",
#       "program": "453",
#       "program_id": "SAO-21",
#       "tac_priority": 2,
#       "pi_priority": "1",
#       "max_seeing": null,
#       "duration": "3600",
#       "overhead": "1800",
#       "objtype": "longslit",
#       "mask_id": "111",
#       "mask": "Longslit1",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7962",
#       "objid_id": "913",
#       "objid": "J1029+6115-1",
#       "complete": "False",
#       "ra_hms": "10h29m27.53s",
#       "dec_dms": "+61d15m05.3s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "Oldham",
#       "program": "453",
#       "program_id": "SAO-21",
#       "tac_priority": 2,
#       "pi_priority": "1",
#       "max_seeing": null,
#       "duration": "7200",
#       "overhead": "1800",
#       "objtype": "longslit",
#       "mask_id": "111",
#       "mask": "Longslit1",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7964",
#       "objid_id": "948",
#       "objid": "J0219",
#       "complete": "False",
#       "ra_hms": "02h19m10.59s",
#       "dec_dms": "-05d51m14.9s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "MacLeod",
#       "program": "455",
#       "program_id": "SAO-1M",
#       "tac_priority": 2,
#       "pi_priority": "1",
#       "max_seeing": null,
#       "duration": "900",
#       "overhead": "1800",
#       "objtype": "longslit",
#       "mask_id": "111",
#       "mask": "Longslit1",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7968",
#       "objid_id": "949",
#       "objid": "J0156",
#       "complete": "False",
#       "ra_hms": "01h56m33.56s",
#       "dec_dms": "+00d57m49.1s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "MacLeod",
#       "program": "455",
#       "program_id": "SAO-1M",
#       "tac_priority": 2,
#       "pi_priority": "1",
#       "max_seeing": null,
#       "duration": "1800",
#       "overhead": "1800",
#       "objtype": "longslit",
#       "mask_id": "111",
#       "mask": "Longslit1",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7966",
#       "objid_id": "947",
#       "objid": "J0152",
#       "complete": "False",
#       "ra_hms": "01h52m58.66s",
#       "dec_dms": "+01d05m07.4s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "MacLeod",
#       "program": "455",
#       "program_id": "SAO-1M",
#       "tac_priority": 2,
#       "pi_priority": "1",
#       "max_seeing": null,
#       "duration": "1800",
#       "overhead": "1800",
#       "objtype": "longslit",
#       "mask_id": "111",
#       "mask": "Longslit1",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7967",
#       "objid_id": "950",
#       "objid": "J0139",
#       "complete": "False",
#       "ra_hms": "01h39m43.10s",
#       "dec_dms": "+06d12m54.0s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "MacLeod",
#       "program": "455",
#       "program_id": "SAO-1M",
#       "tac_priority": 2,
#       "pi_priority": "2",
#       "max_seeing": null,
#       "duration": "1800",
#       "overhead": "1800",
#       "objtype": "longslit",
#       "mask_id": "111",
#       "mask": "Longslit1",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7965",
#       "objid_id": "953",
#       "objid": "J0107",
#       "complete": "False",
#       "ra_hms": "01h07m42.17s",
#       "dec_dms": "+01d00m01.4s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "MacLeod",
#       "program": "455",
#       "program_id": "SAO-1M",
#       "tac_priority": 2,
#       "pi_priority": "2",
#       "max_seeing": null,
#       "duration": "1800",
#       "overhead": "1800",
#       "objtype": "longslit",
#       "mask_id": "111",
#       "mask": "Longslit1",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7971",
#       "objid_id": "954",
#       "objid": "J0340",
#       "complete": "False",
#       "ra_hms": "03h40m17.33s",
#       "dec_dms": "+00d31m52.6s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "MacLeod",
#       "program": "455",
#       "program_id": "SAO-1M",
#       "tac_priority": 2,
#       "pi_priority": "3",
#       "max_seeing": null,
#       "duration": "1800",
#       "overhead": "1800",
#       "objtype": "longslit",
#       "mask_id": "111",
#       "mask": "Longslit1",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7970",
#       "objid_id": "951",
#       "objid": "J0026",
#       "complete": "False",
#       "ra_hms": "00h26m27.89s",
#       "dec_dms": "-10d10m20.5s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "MacLeod",
#       "program": "455",
#       "program_id": "SAO-1M",
#       "tac_priority": 2,
#       "pi_priority": "3",
#       "max_seeing": null,
#       "duration": "1800",
#       "overhead": "1800",
#       "objtype": "longslit",
#       "mask_id": "111",
#       "mask": "Longslit1",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     },
#     {
#       "block_id": "7969",
#       "objid_id": "952",
#       "objid": "J0254",
#       "complete": "False",
#       "ra_hms": "02h54m28.83s",
#       "dec_dms": "-00d48m34.9s",
#       "epoch": "J2000",
#       "posang": "0",
#       "moon": null,
#       "pi": "MacLeod",
#       "program": "455",
#       "program_id": "SAO-1M",
#       "tac_priority": 2,
#       "pi_priority": "3",
#       "max_seeing": null,
#       "duration": "1800",
#       "overhead": "1800",
#       "objtype": "longslit",
#       "mask_id": "111",
#       "mask": "Longslit1",
#       "time_constraints": [
#         [
#           "2017-12-05T19:00:00",
#           "2017-12-15T19:00:00"
#         ]
#       ]
#     }
#   ]
# }

# %%
schedule_id = meta["schedule_id"]
debug = meta["debug"]
verbose = meta["verbose"]
instrument = meta['instrument']
queuerun_id = meta["queuerun_id"]

# %%
allocation = meta['allocation']
if True:
    txt = json.dumps(allocation, indent=2)
    print(txt)
# Out:
# {
#   "374": 5.99,
#   "385": 2.995,
#   "372": 2.995,
#   "380": 35.94,
#   "373": 5.99,
#   "443": 5.99,
#   "444": 11.98,
#   "445": 5.99,
#   "446": 2.995,
#   "447": 2.995,
#   "448": 2.995,
#   "449": 2.995,
#   "450": 2.995,
#   "376": 17.97,
#   "451": 2.995,
#   "452": 2.995,
#   "453": 2.995,
#   "455": 2.995,
#   "456": 2.995
# }

# %%
stats = meta['stats']
if True:
    txt = json.dumps(stats, indent=2)
    print(txt)
# Out:
# {
#   "374": {
#     "total_nights_allocated": "0.5",
#     "total_exposure_requested": 21600,
#     "total_exposure_used": 0,
#     "total_overhead_requested": 5400,
#     "total_overhead_used": 0,
#     "program_percent_allocated": 5,
#     "program_hours_allocated": 5.99,
#     "total_hours_requested": 7.5,
#     "total_hours_used": 0,
#     "total_used_percent": 0,
#     "notes": 0
#   },
#   "385": {
#     "total_nights_allocated": "0.25",
#     "total_exposure_requested": 36600,
#     "total_exposure_used": 6480,
#     "total_overhead_requested": 19980,
#     "total_overhead_used": 3180,
#     "program_percent_allocated": 2.5,
#     "program_hours_allocated": 2.995,
#     "total_hours_requested": 15.716666666667,
#     "total_hours_used": 2.6833333333333,
#     "total_used_percent": 89.593767390095,
#     "notes": 0
#   },
#   "372": {
#     "total_nights_allocated": "0.25",
#     "total_exposure_requested": 235,
#     "total_exposure_used": 0,
#     "total_overhead_requested": 7500,
#     "total_overhead_used": 0,
#     "program_percent_allocated": 2.5,
#     "program_hours_allocated": 2.995,
#     "total_hours_requested": 2.1486111111111,
#     "total_hours_used": 0,
#     "total_used_percent": 0,
#     "notes": 0
#   },
#   "380": {
#     "total_nights_allocated": "3",
#     "total_exposure_requested": 115200,
#     "total_exposure_used": 14400,
#     "total_overhead_requested": 110080,
#     "total_overhead_used": 9280,
#     "program_percent_allocated": 30,
#     "program_hours_allocated": 35.94,
#     "total_hours_requested": 62.577777777778,
#     "total_hours_used": 6.5777777777778,
#     "total_used_percent": 18.302108452359,
#     "notes": 0
#   },
#   "373": {
#     "total_nights_allocated": "0.5",
#     "total_exposure_requested": 26400,
#     "total_exposure_used": 0,
#     "total_overhead_requested": 9000,
#     "total_overhead_used": 0,
#     "program_percent_allocated": 5,
#     "program_hours_allocated": 5.99,
#     "total_hours_requested": 9.8333333333333,
#     "total_hours_used": 0,
#     "total_used_percent": 0,
#     "notes": 0
#   },
#   "443": {
#     "total_nights_allocated": "0.5",
#     "total_exposure_requested": 12000,
#     "total_exposure_used": 0,
#     "total_overhead_requested": 3600,
#     "total_overhead_used": 0,
#     "program_percent_allocated": 5,
#     "program_hours_allocated": 5.99,
#     "total_hours_requested": 4.3333333333333,
#     "total_hours_used": 0,
#     "total_used_percent": 0,
#     "notes": 0
#   },
#   "444": {
#     "total_nights_allocated": "1",
#     "total_exposure_requested": 75600,
#     "total_exposure_used": 14400,
#     "total_overhead_requested": 36300,
#     "total_overhead_used": 5700,
#     "program_percent_allocated": 10,
#     "program_hours_allocated": 11.98,
#     "total_hours_requested": 31.083333333333,
#     "total_hours_used": 5.5833333333333,
#     "total_used_percent": 46.605453533667,
#     "notes": 0
#   },
#   "445": {
#     "total_nights_allocated": "0.5",
#     "total_exposure_requested": 28800,
#     "total_exposure_used": 3600,
#     "total_overhead_requested": 14160,
#     "total_overhead_used": 1560,
#     "program_percent_allocated": 5,
#     "program_hours_allocated": 5.99,
#     "total_hours_requested": 11.933333333333,
#     "total_hours_used": 1.4333333333333,
#     "total_used_percent": 23.92877017251,
#     "notes": 0
#   },
#   "446": {
#     "total_nights_allocated": "0.25",
#     "total_exposure_requested": 23850,
#     "total_exposure_used": 0,
#     "total_overhead_requested": 27300,
#     "total_overhead_used": 0,
#     "program_percent_allocated": 2.5,
#     "program_hours_allocated": 2.995,
#     "total_hours_requested": 14.208333333333,
#     "total_hours_used": 0,
#     "total_used_percent": 0,
#     "notes": 0
#   },
#   "447": {
#     "total_nights_allocated": "0.25",
#     "total_exposure_requested": 13200,
#     "total_exposure_used": 0,
#     "total_overhead_requested": 7200,
#     "total_overhead_used": 0,
#     "program_percent_allocated": 2.5,
#     "program_hours_allocated": 2.995,
#     "total_hours_requested": 5.6666666666667,
#     "total_hours_used": 0,
#     "total_used_percent": 0,
#     "notes": 0
#   },
#   "448": {
#     "total_nights_allocated": "0.25",
#     "total_exposure_requested": 28800,
#     "total_exposure_used": 3600,
#     "total_overhead_requested": 7200,
#     "total_overhead_used": 900,
#     "program_percent_allocated": 2.5,
#     "program_hours_allocated": 2.995,
#     "total_hours_requested": 10,
#     "total_hours_used": 1.25,
#     "total_used_percent": 41.736227045075,
#     "notes": 0
#   },
#   "449": {
#     "total_nights_allocated": "0.25",
#     "total_exposure_requested": 10800,
#     "total_exposure_used": 3600,
#     "total_overhead_requested": 4800,
#     "total_overhead_used": 1200,
#     "program_percent_allocated": 2.5,
#     "program_hours_allocated": 2.995,
#     "total_hours_requested": 4.3333333333333,
#     "total_hours_used": 1.3333333333333,
#     "total_used_percent": 44.518642181413,
#     "notes": 0
#   },
#   "450": {
#     "total_nights_allocated": "0.25",
#     "total_exposure_requested": 9600,
#     "total_exposure_used": 480,
#     "total_overhead_requested": 3600,
#     "total_overhead_used": 360,
#     "program_percent_allocated": 2.5,
#     "program_hours_allocated": 2.995,
#     "total_hours_requested": 3.6666666666667,
#     "total_hours_used": 0.23333333333333,
#     "total_used_percent": 7.7907623817474,
#     "notes": 0
#   },
#   "376": {
#     "total_nights_allocated": "1.5",
#     "total_exposure_requested": 54000,
#     "total_exposure_used": 9000,
#     "total_overhead_requested": 21180,
#     "total_overhead_used": 3180,
#     "program_percent_allocated": 15,
#     "program_hours_allocated": 17.97,
#     "total_hours_requested": 20.883333333333,
#     "total_hours_used": 3.3833333333333,
#     "total_used_percent": 18.827675755889,
#     "notes": 0
#   },
#   "451": {
#     "total_nights_allocated": "0.25",
#     "total_exposure_requested": 11160,
#     "total_exposure_used": 0,
#     "total_overhead_requested": 55800,
#     "total_overhead_used": 0,
#     "program_percent_allocated": 2.5,
#     "program_hours_allocated": 2.995,
#     "total_hours_requested": 18.6,
#     "total_hours_used": 0,
#     "total_used_percent": 0,
#     "notes": 0
#   },
#   "452": {
#     "total_nights_allocated": "0.25",
#     "total_exposure_requested": 13440,
#     "total_exposure_used": 0,
#     "total_overhead_requested": 12600,
#     "total_overhead_used": 0,
#     "program_percent_allocated": 2.5,
#     "program_hours_allocated": 2.995,
#     "total_hours_requested": 7.2333333333333,
#     "total_hours_used": 0,
#     "total_used_percent": 0,
#     "notes": 0
#   },
#   "453": {
#     "total_nights_allocated": "0.25",
#     "total_exposure_requested": 10800,
#     "total_exposure_used": 0,
#     "total_overhead_requested": 3600,
#     "total_overhead_used": 0,
#     "program_percent_allocated": 2.5,
#     "program_hours_allocated": 2.995,
#     "total_hours_requested": 4,
#     "total_hours_used": 0,
#     "total_used_percent": 0,
#     "notes": 0
#   },
#   "455": {
#     "total_nights_allocated": "0.25",
#     "total_exposure_requested": 13500,
#     "total_exposure_used": 0,
#     "total_overhead_requested": 14400,
#     "total_overhead_used": 0,
#     "program_percent_allocated": 2.5,
#     "program_hours_allocated": 2.995,
#     "total_hours_requested": 7.75,
#     "total_hours_used": 0,
#     "total_used_percent": 0,
#     "notes": 0
#   },
#   "456": {
#     "total_nights_allocated": "0.25",
#     "total_exposure_requested": 43200,
#     "total_exposure_used": 0,
#     "total_overhead_requested": 10800,
#     "total_overhead_used": 0,
#     "program_percent_allocated": 2.5,
#     "program_hours_allocated": 2.995,
#     "total_hours_requested": 15,
#     "total_hours_used": 0,
#     "total_used_percent": 0,
#     "notes": 0
#   }
# }

# %%
configuration = meta['configuration']
if True:
    txt = json.dumps(configuration, indent=2)
    print(txt)
# Out:
# {
#   "transit_constrait_mode": {
#     "id": 536,
#     "parametername": "transit_constrait_mode",
#     "parametervalue": 0,
#     "parametertype": "integer",
#     "observingqueuerunid": 62,
#     "notes": null
#   },
#   "use_transit_constraint": {
#     "id": 535,
#     "parametername": "use_transit_constraint",
#     "parametervalue": "false",
#     "parametertype": "boolean",
#     "observingqueuerunid": 62,
#     "notes": null
#   },
#   "max_mask_angle": {
#     "id": 534,
#     "parametername": "max_mask_angle",
#     "parametervalue": 30,
#     "parametertype": "float",
#     "observingqueuerunid": 62,
#     "notes": null
#   },
#   "use_pi_priority_constraint": {
#     "id": 533,
#     "parametername": "use_pi_priority_constraint",
#     "parametervalue": "true",
#     "parametertype": "boolean",
#     "observingqueuerunid": 62,
#     "notes": null
#   },
#   "max_pi_priority": {
#     "id": 532,
#     "parametername": "max_pi_priority",
#     "parametervalue": 1,
#     "parametertype": "integer",
#     "observingqueuerunid": 62,
#     "notes": null
#   },
#   "min_pi_priority": {
#     "id": 531,
#     "parametername": "min_pi_priority",
#     "parametervalue": 999,
#     "parametertype": "integer",
#     "observingqueuerunid": 62,
#     "notes": null
#   },
#   "use_tac_priority_constraint": {
#     "id": 530,
#     "parametername": "use_tac_priority_constraint",
#     "parametervalue": "False",
#     "parametertype": "boolean",
#     "observingqueuerunid": 62,
#     "notes": null
#   },
#   "max_block_length_seconds": {
#     "id": 529,
#     "parametername": "max_block_length_seconds",
#     "parametervalue": 7200,
#     "parametertype": "integer",
#     "observingqueuerunid": 62,
#     "notes": null
#   },
#   "max_fields": {
#     "id": 528,
#     "parametername": "max_fields",
#     "parametervalue": 999,
#     "parametertype": "integer",
#     "observingqueuerunid": 62,
#     "notes": null
#   },
#   "do_mysql": {
#     "id": 527,
#     "parametername": "do_mysql",
#     "parametervalue": "false",
#     "parametertype": "boolean",
#     "observingqueuerunid": 62,
#     "notes": null
#   },
#   "do_plot_parallactic": {
#     "id": 526,
#     "parametername": "do_plot_parallactic",
#     "parametervalue": "false",
#     "parametertype": "boolean",
#     "observingqueuerunid": 62,
#     "notes": null
#   },
#   "time_resolution_seconds": {
#     "id": 525,
#     "parametername": "time_resolution_seconds",
#     "parametervalue": 20,
#     "parametertype": "float",
#     "observingqueuerunid": 62,
#     "notes": null
#   },
#   "imaging_overhead_seconds": {
#     "id": 524,
#     "parametername": "imaging_overhead_seconds",
#     "parametervalue": 300,
#     "parametertype": "float",
#     "observingqueuerunid": 62,
#     "notes": "From 600 (Richard Cool) to 5 min = 300 sec (Igor Chilingarian), 2016-10-19"
#   },
#   "mask_overhead_seconds": {
#     "id": 523,
#     "parametername": "mask_overhead_seconds",
#     "parametervalue": 1800,
#     "parametertype": "float",
#     "observingqueuerunid": 62,
#     "notes": "From 2700 (Richard Cool) to 30 min = 1800 sec (Joannah Hinz), 2016-10-20"
#   },
#   "longslit_overhead_seconds": {
#     "id": 522,
#     "parametername": "longslit_overhead_seconds",
#     "parametervalue": 1800,
#     "parametertype": "float",
#     "observingqueuerunid": 62,
#     "notes": "From 1800 (Richard Cool) to 20 min = 1200 sec (Igor Chilingarian), 2016-10-19"
#   },
#   "gap_time_hours": {
#     "id": 521,
#     "parametername": "gap_time_hours",
#     "parametervalue": 0.5,
#     "parametertype": "float",
#     "observingqueuerunid": 62,
#     "notes": null
#   },
#   "slew_rate": {
#     "id": 520,
#     "parametername": "slew_rate",
#     "parametervalue": 1,
#     "parametertype": "float",
#     "observingqueuerunid": 62,
#     "notes": null
#   },
#   "slew_duration_seconds": {
#     "id": 519,
#     "parametername": "slew_duration_seconds",
#     "parametervalue": 60,
#     "parametertype": "float",
#     "observingqueuerunid": 62,
#     "notes": null
#   },
#   "moon_separation_degrees": {
#     "id": 518,
#     "parametername": "moon_separation_degrees",
#     "parametervalue": 15,
#     "parametertype": "float",
#     "observingqueuerunid": 62,
#     "notes": null
#   },
#   "max_rot_degrees": {
#     "id": 517,
#     "parametername": "max_rot_degrees",
#     "parametervalue": 179,
#     "parametertype": "float",
#     "observingqueuerunid": 62,
#     "notes": "New 160 (emartin oplog 2016-11-11), Old -164"
#   },
#   "min_alt_degrees": {
#     "id": 516,
#     "parametername": "min_alt_degrees",
#     "parametervalue": 20,
#     "parametertype": "float",
#     "observingqueuerunid": 62,
#     "notes": null
#   },
#   "max_alt_degrees": {
#     "id": 515,
#     "parametername": "max_alt_degrees",
#     "parametervalue": 88,
#     "parametertype": "float",
#     "observingqueuerunid": 62,
#     "notes": null
#   },
#   "max_airmass": {
#     "id": 514,
#     "parametername": "max_airmass",
#     "parametervalue": 2.5,
#     "parametertype": "float",
#     "observingqueuerunid": 62,
#     "notes": null
#   },
#   "min_poor_seeing": {
#     "id": 513,
#     "parametername": "min_poor_seeing",
#     "parametervalue": 1.4,
#     "parametertype": "float",
#     "observingqueuerunid": 62,
#     "notes": null
#   },
#   "max_good_seeing": {
#     "id": 512,
#     "parametername": "max_good_seeing",
#     "parametervalue": 1,
#     "parametertype": "float",
#     "observingqueuerunid": 62,
#     "notes": null
#   },
#   "min_seeing": {
#     "id": 511,
#     "parametername": "min_seeing",
#     "parametervalue": 0.1,
#     "parametertype": "float",
#     "observingqueuerunid": 62,
#     "notes": null
#   },
#   "max_seeing": {
#     "id": 510,
#     "parametername": "max_seeing",
#     "parametervalue": 5,
#     "parametertype": "float",
#     "observingqueuerunid": 62,
#     "notes": null
#   },
#   "max_solar_altitude": {
#     "id": 509,
#     "parametername": "max_solar_altitude",
#     "parametervalue": -12,
#     "parametertype": "integer",
#     "observingqueuerunid": 62,
#     "notes": "Civil -6; Nautical, -12, Astronomical, -18"
#   },
#   "use_minimal_constraints": {
#     "id": 508,
#     "parametername": "use_minimal_constraints",
#     "parametervalue": "false",
#     "parametertype": "boolean",
#     "observingqueuerunid": 62,
#     "notes": null
#   },
#   "use_time_allocation_boolean": {
#     "id": 507,
#     "parametername": "use_time_allocation_boolean",
#     "parametervalue": "false",
#     "parametertype": "boolean",
#     "observingqueuerunid": 62,
#     "notes": "Boolean == True, Float == False"
#   },
#   "use_time_allocation_constraint": {
#     "id": 506,
#     "parametername": "use_time_allocation_constraint",
#     "parametervalue": "true",
#     "parametertype": "boolean",
#     "observingqueuerunid": 62,
#     "notes": null
#   },
#   "use_time_constraint": {
#     "id": 505,
#     "parametername": "use_time_constraint",
#     "parametervalue": "true",
#     "parametertype": "boolean",
#     "observingqueuerunid": 62,
#     "notes": null
#   },
#   "use_rotator_constraint": {
#     "id": 504,
#     "parametername": "use_rotator_constraint",
#     "parametervalue": "true",
#     "parametertype": "boolean",
#     "observingqueuerunid": 62,
#     "notes": null
#   },
#   "use_programmatic_constraint": {
#     "id": 503,
#     "parametername": "use_programmatic_constraint",
#     "parametervalue": "false",
#     "parametertype": "boolean",
#     "observingqueuerunid": 62,
#     "notes": null
#   },
#   "use_moon_separation_constraint": {
#     "id": 502,
#     "parametername": "use_moon_separation_constraint",
#     "parametervalue": "true",
#     "parametertype": "boolean",
#     "observingqueuerunid": 62,
#     "notes": null
#   },
#   "use_moon_illumination_constraint": {
#     "id": 501,
#     "parametername": "use_moon_illumination_constraint",
#     "parametervalue": "false",
#     "parametertype": "boolean",
#     "observingqueuerunid": 62,
#     "notes": null
#   },
#   "use_meridian_constraint": {
#     "id": 500,
#     "parametername": "use_meridian_constraint",
#     "parametervalue": "true",
#     "parametertype": "boolean",
#     "observingqueuerunid": 62,
#     "notes": null
#   },
#   "use_at_night_constraint": {
#     "id": 499,
#     "parametername": "use_at_night_constraint",
#     "parametervalue": "true",
#     "parametertype": "boolean",
#     "observingqueuerunid": 62,
#     "notes": null
#   },
#   "use_altitude_boolean": {
#     "id": 498,
#     "parametername": "use_altitude_boolean",
#     "parametervalue": "false",
#     "parametertype": "boolean",
#     "observingqueuerunid": 62,
#     "notes": null
#   },
#   "use_altitude_constraint": {
#     "id": 497,
#     "parametername": "use_altitude_constraint",
#     "parametervalue": "true",
#     "parametertype": "boolean",
#     "observingqueuerunid": 62,
#     "notes": null
#   },
#   "use_airmass_constraint": {
#     "id": 496,
#     "parametername": "use_airmass_constraint",
#     "parametervalue": "true",
#     "parametertype": "boolean",
#     "observingqueuerunid": 62,
#     "notes": null
#   },
#   "trimester": {
#     "id": 495,
#     "parametername": "trimester",
#     "parametervalue": "2017c",
#     "parametertype": "string",
#     "observingqueuerunid": 62,
#     "notes": null
#   },
#   "mode": {
#     "id": 494,
#     "parametername": "mode",
#     "parametervalue": 1,
#     "parametertype": "integer",
#     "observingqueuerunid": 62,
#     "notes": null
#   },
#   "end_date": {
#     "id": 493,
#     "parametername": "end_date",
#     "parametervalue": "2017-12-15 07:00:00",
#     "parametertype": "datetime",
#     "observingqueuerunid": 62,
#     "notes": null
#   },
#   "start_date": {
#     "id": 492,
#     "parametername": "start_date",
#     "parametervalue": "2017-12-14 22:46:00",
#     "parametertype": "datetime",
#     "observingqueuerunid": 62,
#     "notes": null
#   },
#   "use_mask_angle_constraint": {
#     "id": 491,
#     "parametername": "use_mask_angle_constraint",
#     "parametervalue": "true",
#     "parametertype": "boolean",
#     "observingqueuerunid": 62,
#     "notes": null
#   },
#   "min_rot_degrees": {
#     "id": 490,
#     "parametername": "min_rot_degrees",
#     "parametervalue": -166,
#     "parametertype": "float",
#     "observingqueuerunid": 62,
#     "notes": "New -170 (emartin oplog 2016-11-11), Old -180 "
#   }
# }

# %%
configs = {}
for conf in configuration:
    if False:
        print(conf, ": " ,  repr(configuration[conf]))
    configs[conf] = configuration[conf]['parametervalue']
    if True:
        print (conf, ": ", configs[conf])
# Out:
# transit_constrait_mode :  0
# use_transit_constraint :  false
# max_mask_angle :  30
# use_pi_priority_constraint :  true
# max_pi_priority :  1
# min_pi_priority :  999
# use_tac_priority_constraint :  False
# max_block_length_seconds :  7200
# max_fields :  999
# do_mysql :  false
# do_plot_parallactic :  false
# time_resolution_seconds :  20
# imaging_overhead_seconds :  300
# mask_overhead_seconds :  1800
# longslit_overhead_seconds :  1800
# gap_time_hours :  0.5
# slew_rate :  1
# slew_duration_seconds :  60
# moon_separation_degrees :  15
# max_rot_degrees :  179
# min_alt_degrees :  20
# max_alt_degrees :  88
# max_airmass :  2.5
# min_poor_seeing :  1.4
# max_good_seeing :  1
# min_seeing :  0.1
# max_seeing :  5
# max_solar_altitude :  -12
# use_minimal_constraints :  false
# use_time_allocation_boolean :  false
# use_time_allocation_constraint :  true
# use_time_constraint :  true
# use_rotator_constraint :  true
# use_programmatic_constraint :  false
# use_moon_separation_constraint :  true
# use_moon_illumination_constraint :  false
# use_meridian_constraint :  true
# use_at_night_constraint :  true
# use_altitude_boolean :  false
# use_altitude_constraint :  true
# use_airmass_constraint :  true
# trimester :  2017c
# mode :  1
# end_date :  2017-12-15 07:00:00
# start_date :  2017-12-14 22:46:00
# use_mask_angle_constraint :  true
# min_rot_degrees :  -166

# %%
fields = meta['fields']
if True:
    txt = json.dumps(fields, indent=2)
    print(txt)
# Out:
# [
#   {
#     "block_id": "7993",
#     "objid_id": "1128",
#     "objid": "AT2017hyo",
#     "complete": "False",
#     "ra_hms": "01h21m35.36s",
#     "dec_dms": "+03d17m40.66s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "Blanchard",
#     "program": "385",
#     "program_id": "SAO-14",
#     "tac_priority": 2,
#     "pi_priority": "1",
#     "max_seeing": null,
#     "duration": "2700",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7752",
#     "objid_id": "801",
#     "objid": "PS16aqy (copy)",
#     "complete": "False",
#     "ra_hms": "10h19m02.17s",
#     "dec_dms": "+74d42m24.6s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "Blanchard",
#     "program": "385",
#     "program_id": "SAO-14",
#     "tac_priority": 2,
#     "pi_priority": "1",
#     "max_seeing": null,
#     "duration": "3600",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "8004",
#     "objid_id": "1137",
#     "objid": "AT2017hyo",
#     "complete": "False",
#     "ra_hms": "01h21m35.36s",
#     "dec_dms": "+03d17m40.66s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "Blanchard",
#     "program": "385",
#     "program_id": "SAO-14",
#     "tac_priority": 2,
#     "pi_priority": "1",
#     "max_seeing": null,
#     "duration": "180",
#     "overhead": "300",
#     "objtype": "imaging",
#     "mask_id": "110",
#     "mask": "",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7749",
#     "objid_id": "799",
#     "objid": "PS16aqy (copy)",
#     "complete": "False",
#     "ra_hms": "10h19m02.18s",
#     "dec_dms": "+74d42m24.6s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "Blanchard",
#     "program": "385",
#     "program_id": "SAO-14",
#     "tac_priority": 2,
#     "pi_priority": "1",
#     "max_seeing": null,
#     "duration": "1800",
#     "overhead": "300",
#     "objtype": "imaging",
#     "mask_id": "110",
#     "mask": "",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7999",
#     "objid_id": "1138",
#     "objid": "AT2017hyo",
#     "complete": "False",
#     "ra_hms": "01h21m35.36s",
#     "dec_dms": "+03d17m40.66s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "Blanchard",
#     "program": "385",
#     "program_id": "SAO-14",
#     "tac_priority": 2,
#     "pi_priority": "1",
#     "max_seeing": null,
#     "duration": "180",
#     "overhead": "300",
#     "objtype": "imaging",
#     "mask_id": "110",
#     "mask": "",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "8000",
#     "objid_id": "1139",
#     "objid": "AT2017hyo",
#     "complete": "False",
#     "ra_hms": "01h21m35.36s",
#     "dec_dms": "+03d17m40.66s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "Blanchard",
#     "program": "385",
#     "program_id": "SAO-14",
#     "tac_priority": 2,
#     "pi_priority": "1",
#     "max_seeing": null,
#     "duration": "180",
#     "overhead": "300",
#     "objtype": "imaging",
#     "mask_id": "110",
#     "mask": "",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "8001",
#     "objid_id": "1140",
#     "objid": "PS17dbf",
#     "complete": "False",
#     "ra_hms": "14h34m42.92s",
#     "dec_dms": "+31d29m16.7s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "Blanchard",
#     "program": "385",
#     "program_id": "SAO-14",
#     "tac_priority": 2,
#     "pi_priority": "1",
#     "max_seeing": null,
#     "duration": "900",
#     "overhead": "300",
#     "objtype": "imaging",
#     "mask_id": "110",
#     "mask": "",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7753",
#     "objid_id": "797",
#     "objid": "PS16fgt (copy)",
#     "complete": "False",
#     "ra_hms": "02h44m25.82s",
#     "dec_dms": "+19d10m42.6s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "Blanchard",
#     "program": "385",
#     "program_id": "SAO-14",
#     "tac_priority": 2,
#     "pi_priority": "1",
#     "max_seeing": null,
#     "duration": "900",
#     "overhead": "300",
#     "objtype": "imaging",
#     "mask_id": "110",
#     "mask": "",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7751",
#     "objid_id": "800",
#     "objid": "PS16fgt (copy)",
#     "complete": "False",
#     "ra_hms": "02h44m25.82s",
#     "dec_dms": "+19d10m42.6s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "Blanchard",
#     "program": "385",
#     "program_id": "SAO-14",
#     "tac_priority": 2,
#     "pi_priority": "2",
#     "max_seeing": null,
#     "duration": "5400",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7760",
#     "objid_id": "804",
#     "objid": "Gaia16bvd (copy)",
#     "complete": "False",
#     "ra_hms": "12h32m33.23s",
#     "dec_dms": "+27d07m15.4s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "Blanchard",
#     "program": "385",
#     "program_id": "SAO-14",
#     "tac_priority": 2,
#     "pi_priority": "2",
#     "max_seeing": null,
#     "duration": "1800",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7756",
#     "objid_id": "803",
#     "objid": "PS16fgt  (copy)",
#     "complete": "False",
#     "ra_hms": "02h44m25.82s",
#     "dec_dms": "+19d10m42.6s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "Blanchard",
#     "program": "385",
#     "program_id": "SAO-14",
#     "tac_priority": 2,
#     "pi_priority": "2",
#     "max_seeing": null,
#     "duration": "1080",
#     "overhead": "300",
#     "objtype": "imaging",
#     "mask_id": "110",
#     "mask": "",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7750",
#     "objid_id": "798",
#     "objid": "PS16fgt (copy)",
#     "complete": "False",
#     "ra_hms": "02h44m25.82s",
#     "dec_dms": "+19d10m42.6s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "Blanchard",
#     "program": "385",
#     "program_id": "SAO-14",
#     "tac_priority": 2,
#     "pi_priority": "2",
#     "max_seeing": null,
#     "duration": "960",
#     "overhead": "300",
#     "objtype": "imaging",
#     "mask_id": "110",
#     "mask": "",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7759",
#     "objid_id": "802",
#     "objid": "SN2017egm (copy)",
#     "complete": "False",
#     "ra_hms": "10h19m05.62s",
#     "dec_dms": "+46d27m14.08s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "Blanchard",
#     "program": "385",
#     "program_id": "SAO-14",
#     "tac_priority": 2,
#     "pi_priority": "2",
#     "max_seeing": null,
#     "duration": "300",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7755",
#     "objid_id": "806",
#     "objid": "PS17dqb (copy)",
#     "complete": "False",
#     "ra_hms": "21h35m15.26s",
#     "dec_dms": "-06d58m28.3s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "Blanchard",
#     "program": "385",
#     "program_id": "SAO-14",
#     "tac_priority": 2,
#     "pi_priority": "3",
#     "max_seeing": null,
#     "duration": "3600",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7757",
#     "objid_id": "807",
#     "objid": "PS17dqb (copy)",
#     "complete": "False",
#     "ra_hms": "21h35m15.26s",
#     "dec_dms": "-06d58m28.3s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "Blanchard",
#     "program": "385",
#     "program_id": "SAO-14",
#     "tac_priority": 2,
#     "pi_priority": "3",
#     "max_seeing": null,
#     "duration": "300",
#     "overhead": "300",
#     "objtype": "imaging",
#     "mask_id": "110",
#     "mask": "",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7764",
#     "objid_id": "809",
#     "objid": "PS17dqb (copy)",
#     "complete": "False",
#     "ra_hms": "21h35m15.26s",
#     "dec_dms": "-06d58m28.3s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "Blanchard",
#     "program": "385",
#     "program_id": "SAO-14",
#     "tac_priority": 2,
#     "pi_priority": "3",
#     "max_seeing": null,
#     "duration": "360",
#     "overhead": "300",
#     "objtype": "imaging",
#     "mask_id": "110",
#     "mask": "",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7758",
#     "objid_id": "808",
#     "objid": "PS16fgt (copy)",
#     "complete": "False",
#     "ra_hms": "02h44m25.82s",
#     "dec_dms": "+19d10m42.6s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "Blanchard",
#     "program": "385",
#     "program_id": "SAO-14",
#     "tac_priority": 2,
#     "pi_priority": "3",
#     "max_seeing": null,
#     "duration": "900",
#     "overhead": "300",
#     "objtype": "imaging",
#     "mask_id": "110",
#     "mask": "",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7763",
#     "objid_id": "811",
#     "objid": "PS17dqb (copy)",
#     "complete": "False",
#     "ra_hms": "21h35m15.26s",
#     "dec_dms": "-06d58m28.3s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "Blanchard",
#     "program": "385",
#     "program_id": "SAO-14",
#     "tac_priority": 2,
#     "pi_priority": "3",
#     "max_seeing": null,
#     "duration": "240",
#     "overhead": "300",
#     "objtype": "imaging",
#     "mask_id": "110",
#     "mask": "",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "8005",
#     "objid_id": "1127",
#     "objid": "PS17brq",
#     "complete": "False",
#     "ra_hms": "12h32m33.23s",
#     "dec_dms": "+27d07m15.49s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "Blanchard",
#     "program": "385",
#     "program_id": "SAO-14",
#     "tac_priority": 2,
#     "pi_priority": "3",
#     "max_seeing": null,
#     "duration": "300",
#     "overhead": "300",
#     "objtype": "imaging",
#     "mask_id": "110",
#     "mask": "",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7765",
#     "objid_id": "812",
#     "objid": "PS17dqb (copy)",
#     "complete": "False",
#     "ra_hms": "21h35m15.26s",
#     "dec_dms": "-06d58m28.3s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "Blanchard",
#     "program": "385",
#     "program_id": "SAO-14",
#     "tac_priority": 2,
#     "pi_priority": "3",
#     "max_seeing": null,
#     "duration": "180",
#     "overhead": "300",
#     "objtype": "imaging",
#     "mask_id": "110",
#     "mask": "",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7754",
#     "objid_id": "805",
#     "objid": "Gaia16apd (copy)",
#     "complete": "False",
#     "ra_hms": "12h02m51.71s",
#     "dec_dms": "+44d15m27.4s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "Blanchard",
#     "program": "385",
#     "program_id": "SAO-14",
#     "tac_priority": 2,
#     "pi_priority": "3",
#     "max_seeing": null,
#     "duration": "2700",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7766",
#     "objid_id": "796",
#     "objid": "NGC2419 (copy)",
#     "complete": "False",
#     "ra_hms": "07h38m29.63s",
#     "dec_dms": "+38d47m14.72s",
#     "epoch": "J2000",
#     "posang": "90",
#     "moon": null,
#     "pi": "Fabricant",
#     "program": "372",
#     "program_id": "SAO-1",
#     "tac_priority": 2,
#     "pi_priority": "1",
#     "max_seeing": null,
#     "duration": "15",
#     "overhead": "300",
#     "objtype": "imaging",
#     "mask_id": "110",
#     "mask": "",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7864",
#     "objid_id": "818",
#     "objid": "Zahid_COSMOS4",
#     "complete": "False",
#     "ra_hms": "10h00m57.180s",
#     "dec_dms": "+2d13m53.430s",
#     "epoch": "J2000",
#     "posang": "-56",
#     "moon": null,
#     "pi": "Zahid",
#     "program": "445",
#     "program_id": "SAO-1C",
#     "tac_priority": 2,
#     "pi_priority": "1",
#     "max_seeing": null,
#     "duration": "3600",
#     "overhead": "1800",
#     "objtype": "mask",
#     "mask_id": "136",
#     "design_parang": "-35.6777",
#     "mask": "",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7865",
#     "objid_id": "817",
#     "objid": "Zahid_COSMOS3",
#     "complete": "False",
#     "ra_hms": "10h02m14.326s",
#     "dec_dms": "+2d12m49.470s",
#     "epoch": "J2000",
#     "posang": "-59",
#     "moon": null,
#     "pi": "Zahid",
#     "program": "445",
#     "program_id": "SAO-1C",
#     "tac_priority": 2,
#     "pi_priority": "1",
#     "max_seeing": null,
#     "duration": "3600",
#     "overhead": "1800",
#     "objtype": "mask",
#     "mask_id": "135",
#     "design_parang": "-35.9895",
#     "mask": "",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7866",
#     "objid_id": "816",
#     "objid": "Zahid_COSMOS2",
#     "complete": "False",
#     "ra_hms": "9h59m34.435s",
#     "dec_dms": "+2d31m36.850s",
#     "epoch": "J2000",
#     "posang": "-17",
#     "moon": null,
#     "pi": "Zahid",
#     "program": "445",
#     "program_id": "SAO-1C",
#     "tac_priority": 2,
#     "pi_priority": "1",
#     "max_seeing": null,
#     "duration": "3600",
#     "overhead": "1800",
#     "objtype": "mask",
#     "mask_id": "134",
#     "design_parang": "-35.5506",
#     "mask": "",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7881",
#     "objid_id": "835",
#     "objid": "SAO-9_04016+2610 (copy)",
#     "complete": "False",
#     "ra_hms": "04h04m43.22s",
#     "dec_dms": "+26d18m54.5s",
#     "epoch": "J2000.0",
#     "posang": "30",
#     "moon": "bright",
#     "pi": "Kenyon",
#     "program": "446",
#     "program_id": "SAO-1D",
#     "tac_priority": 2,
#     "pi_priority": "1",
#     "max_seeing": "3",
#     "duration": "360",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1long",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7873",
#     "objid_id": "823",
#     "objid": "SAO-9_04295+2251 (copy)",
#     "complete": "False",
#     "ra_hms": "04h32m32.05s",
#     "dec_dms": "+22d57m26.6s",
#     "epoch": "J2000.0",
#     "posang": "68",
#     "moon": "bright",
#     "pi": "Kenyon",
#     "program": "446",
#     "program_id": "SAO-1D",
#     "tac_priority": 2,
#     "pi_priority": "1",
#     "max_seeing": "3",
#     "duration": "900",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1long",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7871",
#     "objid_id": "822",
#     "objid": "SAO-9_04264+2433 (copy)",
#     "complete": "False",
#     "ra_hms": "04h29m30.08s",
#     "dec_dms": "+24d39m55.0s",
#     "epoch": "J2000.0",
#     "posang": "17",
#     "moon": "bright",
#     "pi": "Kenyon",
#     "program": "446",
#     "program_id": "SAO-1D",
#     "tac_priority": 2,
#     "pi_priority": "1",
#     "max_seeing": "3",
#     "duration": "1200",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1long",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7874",
#     "objid_id": "825",
#     "objid": "SAO-9_L1527IRS (copy)",
#     "complete": "False",
#     "ra_hms": "04h39m53.9s",
#     "dec_dms": "+26d03m11s",
#     "epoch": "J2000.0",
#     "posang": "0",
#     "moon": "bright",
#     "pi": "Kenyon",
#     "program": "446",
#     "program_id": "SAO-1D",
#     "tac_priority": 2,
#     "pi_priority": "1",
#     "max_seeing": "3",
#     "duration": "2700",
#     "overhead": "300",
#     "objtype": "imaging",
#     "mask_id": "110",
#     "mask": "",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7885",
#     "objid_id": "836",
#     "objid": "SAO-9_LkHa358 (copy)",
#     "complete": "False",
#     "ra_hms": "04h31m36.13s",
#     "dec_dms": "+18d13m43.2s",
#     "epoch": "J2000.0",
#     "posang": "45",
#     "moon": "bright",
#     "pi": "Kenyon",
#     "program": "446",
#     "program_id": "SAO-1D",
#     "tac_priority": 2,
#     "pi_priority": "2",
#     "max_seeing": "3",
#     "duration": "360",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1long",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7897",
#     "objid_id": "854",
#     "objid": "SAO-9_04361+2547 (copy)",
#     "complete": "False",
#     "ra_hms": "04h39m13.89s",
#     "dec_dms": "+25d53m20.8s",
#     "epoch": "J2000.0",
#     "posang": "76",
#     "moon": "bright",
#     "pi": "Kenyon",
#     "program": "446",
#     "program_id": "SAO-1D",
#     "tac_priority": 2,
#     "pi_priority": "2",
#     "max_seeing": "3",
#     "duration": "1500",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1long",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7895",
#     "objid_id": "845",
#     "objid": "SAO-9_CoKuTau1 (copy)",
#     "complete": "False",
#     "ra_hms": "04h18m51.47s",
#     "dec_dms": "+28d20m26s",
#     "epoch": "J2000.0",
#     "posang": "90",
#     "moon": "bright",
#     "pi": "Kenyon",
#     "program": "446",
#     "program_id": "SAO-1D",
#     "tac_priority": 2,
#     "pi_priority": "2",
#     "max_seeing": "3",
#     "duration": "1500",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1long",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7886",
#     "objid_id": "846",
#     "objid": "SAO-9_L1551NE (copy)",
#     "complete": "False",
#     "ra_hms": "04h31m44.44s",
#     "dec_dms": "+18d08m31.5s",
#     "epoch": "J2000.0",
#     "posang": "140",
#     "moon": "bright",
#     "pi": "Kenyon",
#     "program": "446",
#     "program_id": "SAO-1D",
#     "tac_priority": 2,
#     "pi_priority": "2",
#     "max_seeing": "3",
#     "duration": "1500",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1long",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7887",
#     "objid_id": "844",
#     "objid": "SAO-9_04489+3042 (copy)",
#     "complete": "False",
#     "ra_hms": "04h52m06.68s",
#     "dec_dms": "+30d47m17.5s",
#     "epoch": "J2000.0",
#     "posang": "51",
#     "moon": "bright",
#     "pi": "Kenyon",
#     "program": "446",
#     "program_id": "SAO-1D",
#     "tac_priority": 2,
#     "pi_priority": "3",
#     "max_seeing": "3",
#     "duration": "900",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1long",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7891",
#     "objid_id": "837",
#     "objid": "SAO-9_04239+2436 (copy)",
#     "complete": "False",
#     "ra_hms": "04h26m56.29s",
#     "dec_dms": "+24d43m35.3s",
#     "epoch": "J2000.0",
#     "posang": "149",
#     "moon": "bright",
#     "pi": "Kenyon",
#     "program": "446",
#     "program_id": "SAO-1D",
#     "tac_priority": 2,
#     "pi_priority": "3",
#     "max_seeing": "3",
#     "duration": "900",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1long",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7890",
#     "objid_id": "838",
#     "objid": "SAO-9_04248+2612 (copy)",
#     "complete": "False",
#     "ra_hms": "04h27m57.30s",
#     "dec_dms": "+26d19m18.3s",
#     "epoch": "J2000.0",
#     "posang": "56",
#     "moon": "bright",
#     "pi": "Kenyon",
#     "program": "446",
#     "program_id": "SAO-1D",
#     "tac_priority": 2,
#     "pi_priority": "3",
#     "max_seeing": "3",
#     "duration": "1500",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1long",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7888",
#     "objid_id": "839",
#     "objid": "SAO-9_04381+2540 (copy)",
#     "complete": "False",
#     "ra_hms": "04h41m12.67s",
#     "dec_dms": "+25d46m35.4s",
#     "epoch": "J2000.0",
#     "posang": "86",
#     "moon": "bright",
#     "pi": "Kenyon",
#     "program": "446",
#     "program_id": "SAO-1D",
#     "tac_priority": 2,
#     "pi_priority": "3",
#     "max_seeing": "3",
#     "duration": "1800",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1long",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7902",
#     "objid_id": "853",
#     "objid": "SAO-9_04365+2535 (copy)",
#     "complete": "False",
#     "ra_hms": "04h39m35.19s",
#     "dec_dms": "+25d41m44.7s",
#     "epoch": "J2000.0",
#     "posang": "82",
#     "moon": "bright",
#     "pi": "Kenyon",
#     "program": "446",
#     "program_id": "SAO-1D",
#     "tac_priority": 2,
#     "pi_priority": "4",
#     "max_seeing": "2",
#     "duration": "1500",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1long",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7900",
#     "objid_id": "848",
#     "objid": "SAO-9_04325+2402 (copy)",
#     "complete": "False",
#     "ra_hms": "04h35m35.39s",
#     "dec_dms": "+24d08m19.4s",
#     "epoch": "J2000.0",
#     "posang": "109",
#     "moon": "bright",
#     "pi": "Kenyon",
#     "program": "446",
#     "program_id": "SAO-1D",
#     "tac_priority": 2,
#     "pi_priority": "4",
#     "max_seeing": "2",
#     "duration": "1500",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1long",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7899",
#     "objid_id": "849",
#     "objid": "SAO-9_04302+2247 (copy)",
#     "complete": "False",
#     "ra_hms": "04h33m16.50s",
#     "dec_dms": "+22d53m20.4s",
#     "epoch": "J2000.0",
#     "posang": "178",
#     "moon": "bright",
#     "pi": "Kenyon",
#     "program": "446",
#     "program_id": "SAO-1D",
#     "tac_priority": 2,
#     "pi_priority": "4",
#     "max_seeing": "3",
#     "duration": "1500",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1long",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7903",
#     "objid_id": "850",
#     "objid": "SAO-9_04301+2608 (copy)",
#     "complete": "False",
#     "ra_hms": "04h33m14.36s",
#     "dec_dms": "+26d14m23.5s",
#     "epoch": "J2000.0",
#     "posang": "0",
#     "moon": "bright",
#     "pi": "Kenyon",
#     "program": "446",
#     "program_id": "SAO-1D",
#     "tac_priority": 2,
#     "pi_priority": "4",
#     "max_seeing": "3",
#     "duration": "1800",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1long",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7905",
#     "objid_id": "899",
#     "objid": "jj0151-2",
#     "complete": "False",
#     "ra_hms": "1h51m20.67s",
#     "dec_dms": "+18d12m47.96s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "Brown",
#     "program": "447",
#     "program_id": "SAO-1E",
#     "tac_priority": 2,
#     "pi_priority": "1",
#     "max_seeing": null,
#     "duration": "1200",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7904",
#     "objid_id": "899",
#     "objid": "jj0151-1",
#     "complete": "False",
#     "ra_hms": "1h51m20.67s",
#     "dec_dms": "+18d12m47.96s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "Brown",
#     "program": "447",
#     "program_id": "SAO-1E",
#     "tac_priority": 2,
#     "pi_priority": "1",
#     "max_seeing": null,
#     "duration": "7200",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7906",
#     "objid_id": "901",
#     "objid": "j0900m",
#     "complete": "False",
#     "ra_hms": "9h00m51.516s",
#     "dec_dms": "-04d42m49.18s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "Brown",
#     "program": "447",
#     "program_id": "SAO-1E",
#     "tac_priority": 2,
#     "pi_priority": "2",
#     "max_seeing": null,
#     "duration": "2400",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7907",
#     "objid_id": "900",
#     "objid": "j0859m",
#     "complete": "False",
#     "ra_hms": "8h59m27.222s",
#     "dec_dms": "-04d29m16.34s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "Brown",
#     "program": "447",
#     "program_id": "SAO-1E",
#     "tac_priority": 2,
#     "pi_priority": "2",
#     "max_seeing": null,
#     "duration": "2400",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7909",
#     "objid_id": "917",
#     "objid": "Coma01",
#     "complete": "False",
#     "ra_hms": "13h00m09.712s",
#     "dec_dms": "+27d23m05.300s",
#     "epoch": "J2000",
#     "posang": "169",
#     "moon": null,
#     "pi": "Chilingarian",
#     "program": "448",
#     "program_id": "SAO-1F",
#     "tac_priority": 2,
#     "pi_priority": "1",
#     "max_seeing": null,
#     "duration": "7200",
#     "overhead": 1800,
#     "objtype": "mask",
#     "mask_id": "139",
#     "design_parang": "-72.5335",
#     "mask": "",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7916",
#     "objid_id": "918",
#     "objid": "UDS-2",
#     "complete": "False",
#     "ra_hms": "2h17m28.331s",
#     "dec_dms": "-5d12m14.460s",
#     "epoch": "J2000",
#     "posang": "-152",
#     "moon": null,
#     "pi": "Tacchella",
#     "program": "450",
#     "program_id": "SAO-1H",
#     "tac_priority": 2,
#     "pi_priority": "1",
#     "max_seeing": null,
#     "duration": "2400",
#     "overhead": "1800",
#     "objtype": "mask",
#     "mask_id": "194",
#     "design_parang": "29.4788",
#     "mask": "",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7915",
#     "objid_id": "918",
#     "objid": "UDS-1",
#     "complete": "False",
#     "ra_hms": "2h17m28.331s",
#     "dec_dms": "-5d12m14.460s",
#     "epoch": "J2000",
#     "posang": "-152",
#     "moon": null,
#     "pi": "Tacchella",
#     "program": "450",
#     "program_id": "SAO-1H",
#     "tac_priority": 2,
#     "pi_priority": "1",
#     "max_seeing": null,
#     "duration": "7200",
#     "overhead": "1800",
#     "objtype": "mask",
#     "mask_id": "194",
#     "design_parang": "29.4788",
#     "mask": "",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7982",
#     "objid_id": "1117",
#     "objid": "stream_tri_03",
#     "complete": "False",
#     "ra_hms": "1h24m00.218s",
#     "dec_dms": "+36d24m21.572s",
#     "epoch": "J2000",
#     "posang": "146",
#     "moon": null,
#     "pi": "Bonaca",
#     "program": "376",
#     "program_id": "SAO-5",
#     "tac_priority": 2,
#     "pi_priority": "1",
#     "max_seeing": null,
#     "duration": "4500",
#     "overhead": "1800",
#     "objtype": "mask",
#     "mask_id": "234",
#     "design_parang": "97.1788",
#     "mask": "",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7948",
#     "objid_id": "898",
#     "objid": "Graur_06_TDE2",
#     "complete": "False",
#     "ra_hms": "23h23m48.72s",
#     "dec_dms": "-01d08m10.284s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "Graur",
#     "program": "452",
#     "program_id": "SAO-1K",
#     "tac_priority": 2,
#     "pi_priority": "1",
#     "max_seeing": null,
#     "duration": "1800",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7949",
#     "objid_id": "906",
#     "objid": "Graur_02_PS1-11af",
#     "complete": "False",
#     "ra_hms": "09h57m26.82s",
#     "dec_dms": "+03d14m00.94s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "Graur",
#     "program": "452",
#     "program_id": "SAO-1K",
#     "tac_priority": 2,
#     "pi_priority": "1",
#     "max_seeing": null,
#     "duration": "1800",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7950",
#     "objid_id": "905",
#     "objid": "Graur_02_PS1-11af",
#     "complete": "False",
#     "ra_hms": "09h57m26.82s",
#     "dec_dms": "+03d14m00.94s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "Graur",
#     "program": "452",
#     "program_id": "SAO-1K",
#     "tac_priority": 2,
#     "pi_priority": "1",
#     "max_seeing": null,
#     "duration": "450",
#     "overhead": "300",
#     "objtype": "imaging",
#     "mask_id": "110",
#     "mask": "",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7951",
#     "objid_id": "904",
#     "objid": "Graur_01_SDSSJ0159",
#     "complete": "False",
#     "ra_hms": "01h59m57.64s",
#     "dec_dms": "+00d33m10.49s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "Graur",
#     "program": "452",
#     "program_id": "SAO-1K",
#     "tac_priority": 2,
#     "pi_priority": "1",
#     "max_seeing": null,
#     "duration": "450",
#     "overhead": "300",
#     "objtype": "imaging",
#     "mask_id": "110",
#     "mask": "",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7952",
#     "objid_id": "912",
#     "objid": "Graur_05_D1-9",
#     "complete": "False",
#     "ra_hms": "02h25m17.00s",
#     "dec_dms": "-04d32m59.00s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "Graur",
#     "program": "452",
#     "program_id": "SAO-1K",
#     "tac_priority": 2,
#     "pi_priority": "1",
#     "max_seeing": null,
#     "duration": "1800",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7953",
#     "objid_id": "910",
#     "objid": "Graur_04_2MASXJ0249",
#     "complete": "False",
#     "ra_hms": "02h49m17.31s",
#     "dec_dms": "-04d12m52.1s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "Graur",
#     "program": "452",
#     "program_id": "SAO-1K",
#     "tac_priority": 2,
#     "pi_priority": "1",
#     "max_seeing": null,
#     "duration": "1800",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7954",
#     "objid_id": "908",
#     "objid": "Graur_03_SDSSJ0952",
#     "complete": "False",
#     "ra_hms": "09h52m09.56s",
#     "dec_dms": "+21d43m13.24s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "Graur",
#     "program": "452",
#     "program_id": "SAO-1K",
#     "tac_priority": 2,
#     "pi_priority": "1",
#     "max_seeing": null,
#     "duration": "1800",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7955",
#     "objid_id": "907",
#     "objid": "Graur_03_SDSSJ0952",
#     "complete": "False",
#     "ra_hms": "09h52m09.56s",
#     "dec_dms": "+21d43m13.24s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "Graur",
#     "program": "452",
#     "program_id": "SAO-1K",
#     "tac_priority": 2,
#     "pi_priority": "1",
#     "max_seeing": null,
#     "duration": "420",
#     "overhead": "300",
#     "objtype": "imaging",
#     "mask_id": "110",
#     "mask": "",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7956",
#     "objid_id": "911",
#     "objid": "Graur_05_D1-9",
#     "complete": "False",
#     "ra_hms": "02h25m17.00s",
#     "dec_dms": "-04d32m59.00s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "Graur",
#     "program": "452",
#     "program_id": "SAO-1K",
#     "tac_priority": 2,
#     "pi_priority": "2",
#     "max_seeing": null,
#     "duration": "450",
#     "overhead": "300",
#     "objtype": "imaging",
#     "mask_id": "110",
#     "mask": "",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7957",
#     "objid_id": "902",
#     "objid": "Graur_06_TDE2",
#     "complete": "False",
#     "ra_hms": "23h23m48.72s",
#     "dec_dms": "-01d08m10.284s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "Graur",
#     "program": "452",
#     "program_id": "SAO-1K",
#     "tac_priority": 2,
#     "pi_priority": "2",
#     "max_seeing": null,
#     "duration": "450",
#     "overhead": "300",
#     "objtype": "imaging",
#     "mask_id": "110",
#     "mask": "",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7958",
#     "objid_id": "903",
#     "objid": "Graur_01_SDSSJ0159",
#     "complete": "False",
#     "ra_hms": "01h59m57.64s",
#     "dec_dms": "+00d33m10.49s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "Graur",
#     "program": "452",
#     "program_id": "SAO-1K",
#     "tac_priority": 2,
#     "pi_priority": "3",
#     "max_seeing": null,
#     "duration": "1800",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7959",
#     "objid_id": "909",
#     "objid": "Graur_04_2MASXJ0249",
#     "complete": "False",
#     "ra_hms": "02h49m17.31s",
#     "dec_dms": "-04d12m52.1s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "Graur",
#     "program": "452",
#     "program_id": "SAO-1K",
#     "tac_priority": 2,
#     "pi_priority": "3",
#     "max_seeing": null,
#     "duration": "420",
#     "overhead": "300",
#     "objtype": "imaging",
#     "mask_id": "110",
#     "mask": "",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7963",
#     "objid_id": "913",
#     "objid": "J1029+6115-2",
#     "complete": "False",
#     "ra_hms": "10h29m27.53s",
#     "dec_dms": "+61d15m05.3s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "Oldham",
#     "program": "453",
#     "program_id": "SAO-21",
#     "tac_priority": 2,
#     "pi_priority": "1",
#     "max_seeing": null,
#     "duration": "3600",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7962",
#     "objid_id": "913",
#     "objid": "J1029+6115-1",
#     "complete": "False",
#     "ra_hms": "10h29m27.53s",
#     "dec_dms": "+61d15m05.3s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "Oldham",
#     "program": "453",
#     "program_id": "SAO-21",
#     "tac_priority": 2,
#     "pi_priority": "1",
#     "max_seeing": null,
#     "duration": "7200",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7964",
#     "objid_id": "948",
#     "objid": "J0219",
#     "complete": "False",
#     "ra_hms": "02h19m10.59s",
#     "dec_dms": "-05d51m14.9s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "MacLeod",
#     "program": "455",
#     "program_id": "SAO-1M",
#     "tac_priority": 2,
#     "pi_priority": "1",
#     "max_seeing": null,
#     "duration": "900",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7968",
#     "objid_id": "949",
#     "objid": "J0156",
#     "complete": "False",
#     "ra_hms": "01h56m33.56s",
#     "dec_dms": "+00d57m49.1s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "MacLeod",
#     "program": "455",
#     "program_id": "SAO-1M",
#     "tac_priority": 2,
#     "pi_priority": "1",
#     "max_seeing": null,
#     "duration": "1800",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7966",
#     "objid_id": "947",
#     "objid": "J0152",
#     "complete": "False",
#     "ra_hms": "01h52m58.66s",
#     "dec_dms": "+01d05m07.4s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "MacLeod",
#     "program": "455",
#     "program_id": "SAO-1M",
#     "tac_priority": 2,
#     "pi_priority": "1",
#     "max_seeing": null,
#     "duration": "1800",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7967",
#     "objid_id": "950",
#     "objid": "J0139",
#     "complete": "False",
#     "ra_hms": "01h39m43.10s",
#     "dec_dms": "+06d12m54.0s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "MacLeod",
#     "program": "455",
#     "program_id": "SAO-1M",
#     "tac_priority": 2,
#     "pi_priority": "2",
#     "max_seeing": null,
#     "duration": "1800",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7965",
#     "objid_id": "953",
#     "objid": "J0107",
#     "complete": "False",
#     "ra_hms": "01h07m42.17s",
#     "dec_dms": "+01d00m01.4s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "MacLeod",
#     "program": "455",
#     "program_id": "SAO-1M",
#     "tac_priority": 2,
#     "pi_priority": "2",
#     "max_seeing": null,
#     "duration": "1800",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7971",
#     "objid_id": "954",
#     "objid": "J0340",
#     "complete": "False",
#     "ra_hms": "03h40m17.33s",
#     "dec_dms": "+00d31m52.6s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "MacLeod",
#     "program": "455",
#     "program_id": "SAO-1M",
#     "tac_priority": 2,
#     "pi_priority": "3",
#     "max_seeing": null,
#     "duration": "1800",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7970",
#     "objid_id": "951",
#     "objid": "J0026",
#     "complete": "False",
#     "ra_hms": "00h26m27.89s",
#     "dec_dms": "-10d10m20.5s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "MacLeod",
#     "program": "455",
#     "program_id": "SAO-1M",
#     "tac_priority": 2,
#     "pi_priority": "3",
#     "max_seeing": null,
#     "duration": "1800",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   },
#   {
#     "block_id": "7969",
#     "objid_id": "952",
#     "objid": "J0254",
#     "complete": "False",
#     "ra_hms": "02h54m28.83s",
#     "dec_dms": "-00d48m34.9s",
#     "epoch": "J2000",
#     "posang": "0",
#     "moon": null,
#     "pi": "MacLeod",
#     "program": "455",
#     "program_id": "SAO-1M",
#     "tac_priority": 2,
#     "pi_priority": "3",
#     "max_seeing": null,
#     "duration": "1800",
#     "overhead": "1800",
#     "objtype": "longslit",
#     "mask_id": "111",
#     "mask": "Longslit1",
#     "time_constraints": [
#       [
#         "2017-12-05T19:00:00",
#         "2017-12-15T19:00:00"
#       ]
#     ]
#   }
# ]

# %%
def get_name(f):
    my_name = f['objid'] + '_' +f['block_id'] + "_P" + str(f['pi_priority'])
    if False:
        print("my_name: ", my_name)
    return my_name

# %%
objids = {}
block_ids = {}
objid_ids = {}
# time_constraints': [['2017-12-05T19:00:00', '2017-12-15T19:00:00']]
completes = {}
ra_hmses = {}
dec_dmses = {}
epoches = {}
posangs = {}
moons = {}
pis = {}
programs = {}
program_ids = {}
tac_priorities = {}
pi_priorities = {}
names = {}
max_seeings = {}
durations = {}
overheads = {}
objtypes = {}
block_ids = {}
objid_ids = {}
mask_ids = {}
masks = {}
time_constraints = {}
constraint_scores = {}
for field in fields:
    skycoord = SkyCoord(field['ra_hms'], field['dec_dms'])
    # name = get_name(field)
    name = str(skycoord)
    if True:
        print("Processing: ", name)
    objids[name] = field['objid']
    block_ids[name] = field['block_id']
    objid_ids[name]= field['objid_id']
    completes[name] = field['complete']
    ra_hmses[name] = field['ra_hms']
    dec_dmses[name] = field['dec_dms']
    epoches[name] = field['epoch']
    posangs[name] = field['posang']
    programs[name] = field['program']
    program_ids[name] = field['program_id']
    moons[name] = field['moon']
    pis[name] = field['pi']
    tac_priorities[name] = field['tac_priority']
    pi_priorities[name] = field['pi_priority']
    max_seeings[name] = field['max_seeing']
    objtypes[name] = field['objtype'] 
    durations[name] = field['duration']
    overheads[name] = field['overhead']
    block_ids[name] = field['block_id']
    objid_ids[name] = field['objid_id']
    mask_ids[name] = field['mask_id']
    masks[name] = field['mask']
    time_constraints[name] = field['time_constraints']
    constraint_scores[name] = None
# Out:
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 20.39733333,  3.29462778)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 154.75904167,  74.70683333)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 20.39733333,  3.29462778)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 154.75908333,  74.70683333)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 20.39733333,  3.29462778)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 20.39733333,  3.29462778)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 218.67883333,  31.48797222)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 41.10758333,  19.1785)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 41.10758333,  19.1785)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 188.13845833,  27.12094444)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 41.10758333,  19.1785)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 41.10758333,  19.1785)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 154.77341667,  46.45391111)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 323.81358333, -6.97452778)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 323.81358333, -6.97452778)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 323.81358333, -6.97452778)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 41.10758333,  19.1785)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 323.81358333, -6.97452778)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 188.13845833,  27.12096944)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 323.81358333, -6.97452778)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 180.71545833,  44.25761111)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 114.62345833,  38.78742222)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 150.23825,  2.23150833)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 150.55969167,  2.21374167)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 149.89347917,  2.52690278)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 61.18008333,  26.31513889)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 68.13354167,  22.95738889)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 67.37533333,  24.66527778)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 69.97458333,  26.05305556)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 67.90054167,  18.22866667)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 69.807875,  25.88911111)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 64.71445833,  28.34055556)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 67.93516667,  18.14208333)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 73.02783333,  30.78819444)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 66.73454167,  24.72647222)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 66.98875,  26.32175)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 70.30279167,  25.7765)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 69.896625,  25.69575)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 68.89745833,  24.13872222)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 68.31875,  22.889)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 68.30983333,  26.23986111)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 27.836125,  18.21332222)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 27.836125,  18.21332222)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 135.21465, -4.71366111)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 134.863425, -4.48787222)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 195.04046667,  27.38480556)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 34.36804583, -5.20401667)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 34.36804583, -5.20401667)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 21.00090833,  36.40599222)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 350.953, -1.13619)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 149.36175,  3.23359444)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 149.36175,  3.23359444)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 29.99016667,  0.55291389)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 36.32083333, -4.54972222)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 42.322125, -4.21447222)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 148.03983333,  21.72034444)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 148.03983333,  21.72034444)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 36.32083333, -4.54972222)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 350.953, -1.13619)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 29.99016667,  0.55291389)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 42.322125, -4.21447222)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 157.36470833,  61.25147222)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 157.36470833,  61.25147222)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 34.794125, -5.85413889)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 29.13983333,  0.96363889)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 28.24441667,  1.08538889)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 24.92958333,  6.215)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 16.92570833,  1.00038889)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 55.07220833,  0.53127778)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 6.61620833, -10.17236111)>
# Processing:  <SkyCoord (ICRS): (ra, dec) in deg
#     ( 43.620125, -0.80969444)>

# %%
mmto = Observer(longitude=249.11499999999998*u.deg,
                                 latitude=31.688333333333333*u.deg, 
                                 elevation=2608*u.m,
                                 name="mmto",
                                 timezone="America/Phoenix")
times = Time(["2017-08-01 06:00", "2017-08-01 12:00", "2017-08-01 18:00"])

# %%
print(mmto)
# Out:
# <Observer: name='mmto',
#     location (lon, lat, el)=(-110.88500000000002 deg, 31.688333333333325 deg, 2607.999999999073 m),
#     timezone=<DstTzInfo 'America/Phoenix' LMT-1 day, 16:32:00 STD>>

# %%
# Read in the table of targets
# from astropy.io import ascii
# target_table = ascii.read('targets.txt')
#targets = [FixedTarget(coord=SkyCoord(ra=ra*u.deg, dec=dec*u.deg), name=name)
#           for name, ra, dec in target_table]

# %%
targets = []
for field in fields:
    name = get_name(field)
    if False:
        print("name: ", name)
    r = field['ra_hms']
    d = field['dec_dms']
    if False:
        print("ra: ", repr(r))
        print("dec: ", repr(d))
    targets.append(FixedTarget(coord=SkyCoord(ra=r, dec=d), name=name))

# %%
if False:
    print(targets)

# %%
conn = sqlite3.connect(sqlite_file)
conn.row_factory = dict_factory

# %%
# Define an astroplan constraint for the distance of the target from the meridian.
# The returned value is either a boolean [0,1] if the target is outside of an allowed time
# from meridian transit or a float from [0.0:1.0], where the value is 1.0
# when the target is o/typen the meridian to 0.0 when it is at the anti-meridian (12 hours from the meridian)
class MeridianConstraint(Constraint):
    """Constrains the time for targets from meridian transit.

    Principal investigators (PI's) are required to assigned an integer priority from 1 (highest) to 3 (lowest) to each of their targets.
    The targets should be equally divided into the three priorities (i.e., 1, 2, and 3) so that 1/3 of the requested time correspondes to each
    priority.
    This equal division into the three priorities by even time requested is needed to keep scheduling fair for all projects.
    Every effort will be made to observe all targets, but PI's should anticipate that at least part of their priority 3 targets will not be observed because of poor weather or other causes.


    """
    def __init__(self, mode="sunset",
                 min_alt_degrees=20 * u.deg,
                 max_solar_altitude=-12 * u.deg,
                 grid_times_targets=False, 
                 debug=False):
        """
        Parameters
        ----------
        max : `~astropy.units.Quantity` or `None` (optional)
            Maximum acceptable separation (in decimal hours) between meridian and target (inclusive).
            `None` indicates no constraint of how far the target can be from the meridian.
        boolean_constraint : bool
            If True, the constraint is treated as a boolean (True for within the
            limits and False for outside).  If False, the constraint returns a
            float on [0, 1], where 0 is when the target is on the anti-meridian and
            1 is when the target is on the meridian.
        """
        self.mode = mode 
        self.min_alt_degrees = min_alt_degrees
        self.max_solar_altitude = max_solar_altitude
        self.grid_times_targets = grid_times_targets
        self.debug = debug
        

    def compute_constraint(self, times, observer, targets):
        """
        The MeridianConstraint is calculated by: 1) determining the number of hours the target is from the meridian, and 2) calculating a constraint using Math.abs((12. - hours_from_meridan)/12.0) for the target's position at the beginning, middle, and end of the observing block.  
        The calculated scores for these three times will be different.  
        This causes the constraint to equal 1.0 on the meridian and 0.0 on the anti-meridian (12 hours away).  
        Since the absolute value is used, it doesn't matter which direction the target is from the meridan, i.e., positive hours or negative hours.  Values will always vary from 1.0 to 0.0
        It is possible that the target passes through the meridian during the observing block, i.e., it "transits". 
        Caution should be used in cases where the target transits in that azimuth velocities can be very large if the target is close to zenith.
        The maximum AltitudeConstraint should help prevent extremely large azimuth velocities.  

        It should be remembered that constraint scores are calculated at the beginning, middle, and end of each observing block as part of score for the block.
        This causes the constraint to be multiplied by itself three times and the constraint to vary as 1/X^^3 rather than 1/X.

        """
        
        # 12 hours: the maximum possible time for a target to be from the meridian 
        seconds_in_12hrs = 43200     # 12 hours ==> 12 * 60 * 60 = 43200 seconds
        
        # Set up to TimeDelta constatnt values for future use.
        dt_0hrs = TimeDelta(0,format='sec')
        dt_1hrs = TimeDelta(3600,format='sec')
        dt_1_5hrs = TimeDelta(3600*1.5,format='sec')
        dt_2hrs = TimeDelta(3600*2.0,format='sec')
        dt_2_5hrs = TimeDelta(3600*2.5,format='sec')
        dt_3hrs = TimeDelta(3600*3.0,format='sec')
        dt_3_5hrs = TimeDelta(3600*3.5,format='sec')
        dt_4hrs = TimeDelta(3600*4.0,format='sec')
                
        
        
        # This list will eventually be of length = len(targets) * len(times).
        # We'll reshape it when done.
        # To do:  See if there is a way to user more numpy functions for these
        # calculations to speed things up.
        mask=[]
        
        for target in targets:
            print("target: ", target)
            """
            if False:
                # This is a short-circuit to speed up computation.
                #
                # If the altitude is below the minimum allowed altitude,
                # assign zero's to all times for this target.
                # 
                # In reality, the scores for one or more times within the 
                # observing block could be greater than zero, but
                # the constraint will fail overall for the target since 
                # there is at least one zero score.
            
                cached_altaz = _get_altaz(times, observer, target)
                alt = cached_altaz['altaz'].alt
                
                # Step 1: Check if altitudes are below the minimum allowed
                #       altitude.  This allows short-circuiting of the constraint
                #       calculation to improve efficiency.
                #       If the target is below the minimum altitude,
                #       the overall score for the target will be zero anyway.
                alt_check = alt < self.min_alt_degrees

                # Step 2: This is the special case where the target is below 
                # the lower allowed altitude at any time of the time slot.  
                # The scores for all times for this target will be set to zero.
                if alt_check.any() == True:
                    if self.debug:
                        print("alt is less than minimum: %s, %s" % (alt.degree, self.min_alt_degrees))
                    
                    # Adding a list of zeros of length = len(times)
                    mask += [0.0] * len(times)
            
            # Otherwise, we need to look in detail for each time.
            else:
            """
            if True:
                for time in times:
                    key = get_key(self, target.name, time)
                    obj = get_score(key)
                    if obj is not None:
                        score = obj['value']
                        if False:
                            print("Using saved score.", score)  
                    
                    else:
                        # We do a series of tests to see if the observing block is 
                        # is setting early in the evening.  We want to give high
                        # priority to PIPriority == 1 observing blocks that are
                        # setting near sunset and that can still be observed.
                        #
                        # We take into account the duration of observing blocks
                        # when doing this special "sunset" mode.
                        #
                        # Step 3:  Get the time of the previous sunset.
                        #       This will be used to see if the time is close to sunset.
                        prev_sun_set_time = observer.sun_set_time(time, 
                                            which='previous', 
                                            horizon=self.max_solar_altitude)

                        # Step 4: Calculate the time from the previous sunset.  
                        #        This is an indication of how close we are to sunset.
                        #        It will be a small number if we are trying to observe
                        #        just after sunset.
                        td1 = time - prev_sun_set_time 

                        # Step 5: Get the time of the next target rise.
                        #       This will be used to see if the target is close to rising
                        #       in the east in the morning.
                        next_target_set = observer.target_set_time(time,target,
                                            which="next", 
                                            horizon=self.min_alt_degrees )

                        # Step 6: Calculate the time from the next target setting.
                        #        This number will be a small positive number when 
                        #        the target is above the western horizon.
                        td2 = next_target_set - time

                        # if False and verbose:
                        #    print("tx1: {}, sec: {}, tx2: {}, sec: {}".format(tx1, tx1.sec, tx2, tx2.sec))

                        # Note: The next three steps use a "sunset" mode where we want to give
                        #       high priority to targets that will be setting within the next 2-4
                        #       hours.  We use a graded approach for scoring, based on the duration
                        #       of the target/observing block.

                        # Step 8: This is the "2-hour-target-duration" sunset special case.  
                        #       Evaluate for targets/observing blocks that are more the
                        #       _2_ hours in duration, and we are within _4_ hours after sunset,
                        #       and the target will be setting within _4_ hours.
                        #       Only do this for priority 1 targets.
                        #       This is our only chance to observe them.
                        #       The score is set to 1.0 to give it the maximum chance of being observed.

                        if self.mode == "sunset" and \
                                td1 <= dt_4hrs and td1 > dt_0hrs and \
                                td2 <= dt_4hrs and td2 > dt_0hrs and \
                                target.duration >= 2.0 * u.hour and \
                                target.pi_priority == 1.0:
                            score = 1.0
                            if verbose:
                                print("Sunset special case (>= 2-hr duration), score:",score)

                        # Step 9: This is the "1-hour-target-duration" sunset special case.  
                        #       Evaluate for targets/observing blocks that are 1-2 hours
                        #       in duration, and we are within _3_ hours after sunset,
                        #       and the target will be setting within _3_ hours.
                        #       Only do this for priority 1 targets.
                        #       This is our only chance to observe them.
                        #       The score is set to 1.0 to give it the maximum chance of being observed.
                        elif self.mode == "sunset" and \
                                td1 <= dt_3hrs and td1 > dt_0hrs and \
                                td2 <= dt_3hrs and td2 > dt_0hrs and \
                                target.duration >= 1.0 * u.hour and \
                                target.pi_priority == 1.0:
                            score = 1.0
                            if verbose:
                                print("Sunset special case, (>= 1-hour and < 2-hour duration) score:",score)

                        # Step 10: This is the "<1-hour-target-duration" sunset special case.  
                        #       Evaluate for targets/observing blocks that are <1 hour
                        #       in duration, and we are within _2_ hours after sunset,
                        #       and the target will be setting within _2_ hours.
                        #       Only do this for priority 1 targets.
                        #       This is our only chance to observe them.
                        #       The score is set to 1.0 to give it the maximum chance of being observed.
                        elif self.mode == "sunset" and \
                                td1 <= dt_2hrs and td1 > dt_0hrs and \
                                td2 <= dt_2hrs and td2 > dt_0hrs and \
                                target.pi_priority == 1.0:
                            score = 1.0
                            if verbose:
                                print("Sunset special case, (any duration) score:",score)

                        # Step 11:  If all of the other conditions have not been true,
                        #       Determine how far the target is from the meridian in seconds
                        #       and divide by 12 hours (== 43200 seconds) 
                        #       The target can be in either rising towards the meridian or
                        #       setting away from the meridian.
                        else:

                            meridian_time = observer.target_meridian_transit_time(time,target,which='nearest')
                            diff = abs(time.unix - meridian_time.unix)

                            # There are times when the meridian time is 24 hours off.
                            # So, the math here accounts for that.
                            # If the time difference is more than 24 hours (43200 seconds), 
                            # subtract 24 hours.
                            if diff > 43200:
                                diff -= 86400 # 24 hours in seconds.
                                # Recheck that we are using an absolute value.
                                diff = abs(diff)

                            # Here is the meridian scoring algorithm.  
                            # The closer to the meridian the closer the score is to one.  
                            # The range of scores is 1.0 (on the meridian) to 
                            # 0.0 (on the anti-meridian).
                            score = 1.0 - (diff / 43200.0)               
                            # Shouldn't need these, but just checking.
                            # The score should already range from 0.0 to 1.0.
                            if score < 0.0:
                                score = 0.0
                            if score > 1.0:
                                score = 1.0
                    
                        # Add to sqlite database
                        set_score(key,score)
                    # Add the new score to the 1-D list.
                    mask.append(score)
            
        if False:
            print("mask")
            print(repr(mask))
            
        # Turn the mask into a numpy array and reshape.
        mask = np.reshape(np.array(mask),[len(targets), len(times)])
            
        if False:
            print("mask")
            print(repr(mask))

# %%
# Define an astroplan constraint for the distance of the target from the meridian.
# The returned value is either a boolean [0,1] if the target is outside of an allowed time
# from meridian transit or a float from [0.0:1.0], where the value is 1.0
# when the target is o/typen the meridian to 0.0 when it is at the anti-meridian (12 hours from the meridian)
class MeridianConstraintOld(Constraint):
    """Constrains the time for targets from meridian transit.

    Principal investigators (PI's) are required to assigned an integer priority from 1 (highest) to 3 (lowest) to each of their targets.
    The targets should be equally divided into the three priorities (i.e., 1, 2, and 3) so that 1/3 of the requested time correspondes to each
    priority.
    This equal division into the three priorities by even time requested is needed to keep scheduling fair for all projects.
    Every effort will be made to observe all targets, but PI's should anticipate that at least part of their priority 3 targets will not be observed because of poor weather or other causes.


    """
    def __init__(self, mode="sunset",
                 min_alt_degrees=20 * u.deg,
                 max_solar_altitude=-12 * u.deg,
                 grid_times_targets=False, 
                 debug=False):
        """
        Parameters
        ----------
        max : `~astropy.units.Quantity` or `None` (optional)
            Maximum acceptable separation (in decimal hours) between meridian and target (inclusive).
            `None` indicates no constraint of how far the target can be from the meridian.
        boolean_constraint : bool
            If True, the constraint is treated as a boolean (True for within the
            limits and False for outside).  If False, the constraint returns a
            float on [0, 1], where 0 is when the target is on the anti-meridian and
            1 is when the target is on the meridian.
        """
        self.mode = mode 
        self.min_alt_degrees = min_alt_degrees
        self.max_solar_altitude = max_solar_altitude
        self.grid_times_targets = grid_times_targets
        self.debug = debug
        

    def compute_constraint(self, times, observer, targets):
        """
        The MeridianConstraint is calculated by: 1) determining the number of hours the target is from the meridian, and 2) calculating a constraint using Math.abs((12. - hours_from_meridan)/12.0) for the target's position at the beginning, middle, and end of the observing block.  
        The calculated scores for these three times will be different.  
        This causes the constraint to equal 1.0 on the meridian and 0.0 on the anti-meridian (12 hours away).  
        Since the absolute value is used, it doesn't matter which direction the target is from the meridan, i.e., positive hours or negative hours.  Values will always vary from 1.0 to 0.0
        It is possible that the target passes through the meridian during the observing block, i.e., it "transits". 
        Caution should be used in cases where the target transits in that azimuth velocities can be very large if the target is close to zenith.
        The maximum AltitudeConstraint should help prevent extremely large azimuth velocities.  

        It should be remembered that constraint scores are calculated at the beginning, middle, and end of each observing block as part of score for the block.
        This causes the constraint to be multiplied by itself three times and the constraint to vary as 1/X^^3 rather than 1/X.

        """
        
        # 12 hours: the maximum possible time for a target to be from the meridian 
        seconds_in_12hrs = 43200     # 12 hours ==> 12 * 60 * 60 = 43200 seconds
        
        # Set up to TimeDelta constatnt values for future use.
        dt_0hrs = TimeDelta(0,format='sec')
        dt_1hrs = TimeDelta(3600,format='sec')
        dt_1_5hrs = TimeDelta(3600*1.5,format='sec')
        dt_2hrs = TimeDelta(3600*2.0,format='sec')
        dt_2_5hrs = TimeDelta(3600*2.5,format='sec')
        dt_3hrs = TimeDelta(3600*3.0,format='sec')
        dt_3_5hrs = TimeDelta(3600*3.5,format='sec')
        dt_4hrs = TimeDelta(3600*4.0,format='sec')
                
        
        
        # This list will eventually be of length = len(targets) * len(times).
        # We'll reshape it when done.
        # To do:  See if there is a way to user more numpy functions for these
        # calculations to speed things up.
        mask=[]
        
        for target in targets:
            print("target: ", target)

            for time in times:
                # We do a series of tests to see if the observing block is 
                # is setting early in the evening.  We want to give high
                # priority to PIPriority == 1 observing blocks that are
                # setting near sunset and that can still be observed.
                #
                # We take into account the duration of observing blocks
                # when doing this special "sunset" mode.
                #
                # Step 3:  Get the time of the previous sunset.
                #       This will be used to see if the time is close to sunset.
                prev_sun_set_time = observer.sun_set_time(time, 
                                    which='previous', 
                                    horizon=self.max_solar_altitude)

                # Step 4: Calculate the time from the previous sunset.  
                #        This is an indication of how close we are to sunset.
                #        It will be a small number if we are trying to observe
                #        just after sunset.
                td1 = time - prev_sun_set_time 

                # Step 5: Get the time of the next target rise.
                #       This will be used to see if the target is close to rising
                #       in the east in the morning.
                next_target_set = observer.target_set_time(time,target,
                                    which="next", 
                                    horizon=self.min_alt_degrees )

                # Step 6: Calculate the time from the next target setting.
                #        This number will be a small positive number when 
                #        the target is above the western horizon.
                td2 = next_target_set - time

                # if False and verbose:
                #    print("tx1: {}, sec: {}, tx2: {}, sec: {}".format(tx1, tx1.sec, tx2, tx2.sec))

                # Note: The next three steps use a "sunset" mode where we want to give
                #       high priority to targets that will be setting within the next 2-4
                #       hours.  We use a graded approach for scoring, based on the duration
                #       of the target/observing block.

                # Step 8: This is the "2-hour-target-duration" sunset special case.  
                #       Evaluate for targets/observing blocks that are more the
                #       _2_ hours in duration, and we are within _4_ hours after sunset,
                #       and the target will be setting within _4_ hours.
                #       Only do this for priority 1 targets.
                #       This is our only chance to observe them.
                #       The score is set to 1.0 to give it the maximum chance of being observed.

                if self.mode == "sunset" and \
                        td1 <= dt_4hrs and td1 > dt_0hrs and \
                        td2 <= dt_4hrs and td2 > dt_0hrs and \
                        target.duration >= 2.0 * u.hour and \
                        target.pi_priority == 1.0:
                    score = 1.0
                    if verbose:
                        print("Sunset special case (>= 2-hr duration), score:",score)

                # Step 9: This is the "1-hour-target-duration" sunset special case.  
                #       Evaluate for targets/observing blocks that are 1-2 hours
                #       in duration, and we are within _3_ hours after sunset,
                #       and the target will be setting within _3_ hours.
                #       Only do this for priority 1 targets.
                #       This is our only chance to observe them.
                #       The score is set to 1.0 to give it the maximum chance of being observed.
                elif self.mode == "sunset" and \
                        td1 <= dt_3hrs and td1 > dt_0hrs and \
                        td2 <= dt_3hrs and td2 > dt_0hrs and \
                        target.duration >= 1.0 * u.hour and \
                        target.pi_priority == 1.0:
                    score = 1.0
                    if verbose:
                        print("Sunset special case, (>= 1-hour and < 2-hour duration) score:",score)

                # Step 10: This is the "<1-hour-target-duration" sunset special case.  
                #       Evaluate for targets/observing blocks that are <1 hour
                #       in duration, and we are within _2_ hours after sunset,
                #       and the target will be setting within _2_ hours.
                #       Only do this for priority 1 targets.
                #       This is our only chance to observe them.
                #       The score is set to 1.0 to give it the maximum chance of being observed.
                elif self.mode == "sunset" and \
                        td1 <= dt_2hrs and td1 > dt_0hrs and \
                        td2 <= dt_2hrs and td2 > dt_0hrs and \
                        target.pi_priority == 1.0:
                    score = 1.0
                    if verbose:
                        print("Sunset special case, (any duration) score:",score)

                # Step 11:  If all of the other conditions have not been true,
                #       Determine how far the target is from the meridian in seconds
                #       and divide by 12 hours (== 43200 seconds) 
                #       The target can be in either rising towards the meridian or
                #       setting away from the meridian.
                else:

                    meridian_time = observer.target_meridian_transit_time(time,target,which='nearest')
                    diff = abs(time.unix - meridian_time.unix)

                    # There are times when the meridian time is 24 hours off.
                    # So, the math here accounts for that.
                    # If the time difference is more than 24 hours (43200 seconds), 
                    # subtract 24 hours.
                    if diff > 43200:
                        diff -= 86400 # 24 hours in seconds.
                        # Recheck that we are using an absolute value.
                        diff = abs(diff)

                    # Here is the meridian scoring algorithm.  
                    # The closer to the meridian the closer the score is to one.  
                    # The range of scores is 1.0 (on the meridian) to 
                    # 0.0 (on the anti-meridian).
                    score = 1.0 - (diff / 43200.0)               
                    # Shouldn't need these, but just checking.
                    # The score should already range from 0.0 to 1.0.
                    if score < 0.0:
                        score = 0.0
                    if score > 1.0:
                        score = 1.0

                # Add to sqlite database
                set_score(key,score)
            # Add the new score to the 1-D list.
            mask.append(score)
            
        if self.debug:
            print("mask")
            print(repr(mask))
            
        # Turn the mask into a numpy array and reshape.
        a = np.reshape(np.array(mask),[len(targets), len(times)])
            
        if self.debug:
            print("a")
            print(repr(a))
        
        return a

# %%
constraints = [MeridianConstraint( grid_times_targets=False, 
                     debug=True) for field in fields]

# %%
if False:
    print(repr(constraints))

# %%
# k = get_key(c, targets[0].name, times[0])
# if True:
#     print("k = ", k)

# %%
if True:
    is_event_observable(constraints, mmto, targets, times)
# Out:
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 154.75904167,  74.70683333)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 154.75908333,  74.70683333)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 218.67883333,  31.48797222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 188.13845833,  27.12094444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 154.77341667,  46.45391111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 188.13845833,  27.12096944)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 180.71545833,  44.25761111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 114.62345833,  38.78742222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 150.23825,  2.23150833)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 150.55969167,  2.21374167)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 149.89347917,  2.52690278)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 61.18008333,  26.31513889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.13354167,  22.95738889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 67.37533333,  24.66527778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 69.97458333,  26.05305556)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 67.90054167,  18.22866667)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 69.807875,  25.88911111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 64.71445833,  28.34055556)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 67.93516667,  18.14208333)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 73.02783333,  30.78819444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 66.73454167,  24.72647222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 66.98875,  26.32175)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 70.30279167,  25.7765)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 69.896625,  25.69575)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.89745833,  24.13872222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.31875,  22.889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.30983333,  26.23986111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 27.836125,  18.21332222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 27.836125,  18.21332222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 135.21465, -4.71366111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 134.863425, -4.48787222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 195.04046667,  27.38480556)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 34.36804583, -5.20401667)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 34.36804583, -5.20401667)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 21.00090833,  36.40599222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 350.953, -1.13619)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 149.36175,  3.23359444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 149.36175,  3.23359444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 29.99016667,  0.55291389)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 36.32083333, -4.54972222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 42.322125, -4.21447222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 148.03983333,  21.72034444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 148.03983333,  21.72034444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 36.32083333, -4.54972222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 350.953, -1.13619)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 29.99016667,  0.55291389)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 42.322125, -4.21447222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 157.36470833,  61.25147222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 157.36470833,  61.25147222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 34.794125, -5.85413889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 29.13983333,  0.96363889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 28.24441667,  1.08538889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 24.92958333,  6.215)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 16.92570833,  1.00038889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 55.07220833,  0.53127778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 6.61620833, -10.17236111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 43.620125, -0.80969444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 154.75904167,  74.70683333)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 154.75908333,  74.70683333)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 218.67883333,  31.48797222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 188.13845833,  27.12094444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 154.77341667,  46.45391111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 188.13845833,  27.12096944)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 180.71545833,  44.25761111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 114.62345833,  38.78742222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 150.23825,  2.23150833)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 150.55969167,  2.21374167)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 149.89347917,  2.52690278)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 61.18008333,  26.31513889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.13354167,  22.95738889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 67.37533333,  24.66527778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 69.97458333,  26.05305556)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 67.90054167,  18.22866667)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 69.807875,  25.88911111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 64.71445833,  28.34055556)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 67.93516667,  18.14208333)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 73.02783333,  30.78819444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 66.73454167,  24.72647222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 66.98875,  26.32175)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 70.30279167,  25.7765)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 69.896625,  25.69575)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.89745833,  24.13872222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.31875,  22.889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.30983333,  26.23986111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 27.836125,  18.21332222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 27.836125,  18.21332222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 135.21465, -4.71366111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 134.863425, -4.48787222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 195.04046667,  27.38480556)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 34.36804583, -5.20401667)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 34.36804583, -5.20401667)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 21.00090833,  36.40599222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 350.953, -1.13619)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 149.36175,  3.23359444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 149.36175,  3.23359444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 29.99016667,  0.55291389)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 36.32083333, -4.54972222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 42.322125, -4.21447222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 148.03983333,  21.72034444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 148.03983333,  21.72034444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 36.32083333, -4.54972222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 350.953, -1.13619)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 29.99016667,  0.55291389)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 42.322125, -4.21447222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 157.36470833,  61.25147222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 157.36470833,  61.25147222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 34.794125, -5.85413889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 29.13983333,  0.96363889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 28.24441667,  1.08538889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 24.92958333,  6.215)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 16.92570833,  1.00038889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 55.07220833,  0.53127778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 6.61620833, -10.17236111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 43.620125, -0.80969444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 154.75904167,  74.70683333)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 154.75908333,  74.70683333)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 218.67883333,  31.48797222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 188.13845833,  27.12094444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 154.77341667,  46.45391111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 188.13845833,  27.12096944)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 180.71545833,  44.25761111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 114.62345833,  38.78742222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 150.23825,  2.23150833)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 150.55969167,  2.21374167)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 149.89347917,  2.52690278)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 61.18008333,  26.31513889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.13354167,  22.95738889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 67.37533333,  24.66527778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 69.97458333,  26.05305556)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 67.90054167,  18.22866667)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 69.807875,  25.88911111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 64.71445833,  28.34055556)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 67.93516667,  18.14208333)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 73.02783333,  30.78819444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 66.73454167,  24.72647222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 66.98875,  26.32175)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 70.30279167,  25.7765)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 69.896625,  25.69575)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.89745833,  24.13872222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.31875,  22.889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.30983333,  26.23986111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 27.836125,  18.21332222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 27.836125,  18.21332222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 135.21465, -4.71366111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 134.863425, -4.48787222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 195.04046667,  27.38480556)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 34.36804583, -5.20401667)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 34.36804583, -5.20401667)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 21.00090833,  36.40599222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 350.953, -1.13619)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 149.36175,  3.23359444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 149.36175,  3.23359444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 29.99016667,  0.55291389)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 36.32083333, -4.54972222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 42.322125, -4.21447222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 148.03983333,  21.72034444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 148.03983333,  21.72034444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 36.32083333, -4.54972222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 350.953, -1.13619)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 29.99016667,  0.55291389)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 42.322125, -4.21447222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 157.36470833,  61.25147222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 157.36470833,  61.25147222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 34.794125, -5.85413889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 29.13983333,  0.96363889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 28.24441667,  1.08538889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 24.92958333,  6.215)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 16.92570833,  1.00038889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 55.07220833,  0.53127778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 6.61620833, -10.17236111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 43.620125, -0.80969444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 154.75904167,  74.70683333)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 154.75908333,  74.70683333)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 218.67883333,  31.48797222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 188.13845833,  27.12094444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 154.77341667,  46.45391111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 188.13845833,  27.12096944)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 180.71545833,  44.25761111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 114.62345833,  38.78742222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 150.23825,  2.23150833)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 150.55969167,  2.21374167)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 149.89347917,  2.52690278)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 61.18008333,  26.31513889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.13354167,  22.95738889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 67.37533333,  24.66527778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 69.97458333,  26.05305556)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 67.90054167,  18.22866667)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 69.807875,  25.88911111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 64.71445833,  28.34055556)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 67.93516667,  18.14208333)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 73.02783333,  30.78819444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 66.73454167,  24.72647222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 66.98875,  26.32175)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 70.30279167,  25.7765)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 69.896625,  25.69575)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.89745833,  24.13872222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.31875,  22.889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.30983333,  26.23986111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 27.836125,  18.21332222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 27.836125,  18.21332222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 135.21465, -4.71366111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 134.863425, -4.48787222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 195.04046667,  27.38480556)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 34.36804583, -5.20401667)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 34.36804583, -5.20401667)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 21.00090833,  36.40599222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 350.953, -1.13619)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 149.36175,  3.23359444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 149.36175,  3.23359444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 29.99016667,  0.55291389)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 36.32083333, -4.54972222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 42.322125, -4.21447222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 148.03983333,  21.72034444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 148.03983333,  21.72034444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 36.32083333, -4.54972222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 350.953, -1.13619)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 29.99016667,  0.55291389)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 42.322125, -4.21447222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 157.36470833,  61.25147222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 157.36470833,  61.25147222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 34.794125, -5.85413889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 29.13983333,  0.96363889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 28.24441667,  1.08538889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 24.92958333,  6.215)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 16.92570833,  1.00038889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 55.07220833,  0.53127778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 6.61620833, -10.17236111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 43.620125, -0.80969444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 154.75904167,  74.70683333)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 154.75908333,  74.70683333)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 218.67883333,  31.48797222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 188.13845833,  27.12094444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 154.77341667,  46.45391111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 188.13845833,  27.12096944)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 180.71545833,  44.25761111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 114.62345833,  38.78742222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 150.23825,  2.23150833)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 150.55969167,  2.21374167)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 149.89347917,  2.52690278)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 61.18008333,  26.31513889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.13354167,  22.95738889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 67.37533333,  24.66527778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 69.97458333,  26.05305556)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 67.90054167,  18.22866667)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 69.807875,  25.88911111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 64.71445833,  28.34055556)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 67.93516667,  18.14208333)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 73.02783333,  30.78819444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 66.73454167,  24.72647222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 66.98875,  26.32175)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 70.30279167,  25.7765)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 69.896625,  25.69575)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.89745833,  24.13872222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.31875,  22.889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.30983333,  26.23986111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 27.836125,  18.21332222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 27.836125,  18.21332222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 135.21465, -4.71366111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 134.863425, -4.48787222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 195.04046667,  27.38480556)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 34.36804583, -5.20401667)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 34.36804583, -5.20401667)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 21.00090833,  36.40599222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 350.953, -1.13619)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 149.36175,  3.23359444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 149.36175,  3.23359444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 29.99016667,  0.55291389)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 36.32083333, -4.54972222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 42.322125, -4.21447222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 148.03983333,  21.72034444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 148.03983333,  21.72034444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 36.32083333, -4.54972222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 350.953, -1.13619)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 29.99016667,  0.55291389)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 42.322125, -4.21447222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 157.36470833,  61.25147222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 157.36470833,  61.25147222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 34.794125, -5.85413889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 29.13983333,  0.96363889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 28.24441667,  1.08538889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 24.92958333,  6.215)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 16.92570833,  1.00038889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 55.07220833,  0.53127778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 6.61620833, -10.17236111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 43.620125, -0.80969444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 154.75904167,  74.70683333)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 154.75908333,  74.70683333)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 218.67883333,  31.48797222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 188.13845833,  27.12094444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 154.77341667,  46.45391111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 188.13845833,  27.12096944)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 180.71545833,  44.25761111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 114.62345833,  38.78742222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 150.23825,  2.23150833)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 150.55969167,  2.21374167)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 149.89347917,  2.52690278)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 61.18008333,  26.31513889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.13354167,  22.95738889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 67.37533333,  24.66527778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 69.97458333,  26.05305556)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 67.90054167,  18.22866667)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 69.807875,  25.88911111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 64.71445833,  28.34055556)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 67.93516667,  18.14208333)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 73.02783333,  30.78819444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 66.73454167,  24.72647222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 66.98875,  26.32175)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 70.30279167,  25.7765)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 69.896625,  25.69575)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.89745833,  24.13872222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.31875,  22.889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.30983333,  26.23986111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 27.836125,  18.21332222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 27.836125,  18.21332222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 135.21465, -4.71366111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 134.863425, -4.48787222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 195.04046667,  27.38480556)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 34.36804583, -5.20401667)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 34.36804583, -5.20401667)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 21.00090833,  36.40599222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 350.953, -1.13619)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 149.36175,  3.23359444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 149.36175,  3.23359444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 29.99016667,  0.55291389)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 36.32083333, -4.54972222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 42.322125, -4.21447222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 148.03983333,  21.72034444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 148.03983333,  21.72034444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 36.32083333, -4.54972222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 350.953, -1.13619)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 29.99016667,  0.55291389)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 42.322125, -4.21447222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 157.36470833,  61.25147222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 157.36470833,  61.25147222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 34.794125, -5.85413889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 29.13983333,  0.96363889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 28.24441667,  1.08538889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 24.92958333,  6.215)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 16.92570833,  1.00038889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 55.07220833,  0.53127778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 6.61620833, -10.17236111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 43.620125, -0.80969444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 154.75904167,  74.70683333)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 154.75908333,  74.70683333)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 218.67883333,  31.48797222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 188.13845833,  27.12094444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 154.77341667,  46.45391111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 188.13845833,  27.12096944)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 180.71545833,  44.25761111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 114.62345833,  38.78742222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 150.23825,  2.23150833)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 150.55969167,  2.21374167)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 149.89347917,  2.52690278)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 61.18008333,  26.31513889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.13354167,  22.95738889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 67.37533333,  24.66527778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 69.97458333,  26.05305556)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 67.90054167,  18.22866667)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 69.807875,  25.88911111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 64.71445833,  28.34055556)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 67.93516667,  18.14208333)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 73.02783333,  30.78819444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 66.73454167,  24.72647222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 66.98875,  26.32175)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 70.30279167,  25.7765)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 69.896625,  25.69575)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.89745833,  24.13872222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.31875,  22.889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.30983333,  26.23986111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 27.836125,  18.21332222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 27.836125,  18.21332222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 135.21465, -4.71366111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 134.863425, -4.48787222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 195.04046667,  27.38480556)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 34.36804583, -5.20401667)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 34.36804583, -5.20401667)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 21.00090833,  36.40599222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 350.953, -1.13619)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 149.36175,  3.23359444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 149.36175,  3.23359444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 29.99016667,  0.55291389)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 36.32083333, -4.54972222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 42.322125, -4.21447222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 148.03983333,  21.72034444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 148.03983333,  21.72034444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 36.32083333, -4.54972222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 350.953, -1.13619)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 29.99016667,  0.55291389)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 42.322125, -4.21447222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 157.36470833,  61.25147222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 157.36470833,  61.25147222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 34.794125, -5.85413889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 29.13983333,  0.96363889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 28.24441667,  1.08538889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 24.92958333,  6.215)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 16.92570833,  1.00038889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 55.07220833,  0.53127778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 6.61620833, -10.17236111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 43.620125, -0.80969444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 154.75904167,  74.70683333)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 154.75908333,  74.70683333)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 218.67883333,  31.48797222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 188.13845833,  27.12094444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 154.77341667,  46.45391111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 188.13845833,  27.12096944)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 180.71545833,  44.25761111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 114.62345833,  38.78742222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 150.23825,  2.23150833)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 150.55969167,  2.21374167)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 149.89347917,  2.52690278)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 61.18008333,  26.31513889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.13354167,  22.95738889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 67.37533333,  24.66527778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 69.97458333,  26.05305556)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 67.90054167,  18.22866667)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 69.807875,  25.88911111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 64.71445833,  28.34055556)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 67.93516667,  18.14208333)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 73.02783333,  30.78819444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 66.73454167,  24.72647222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 66.98875,  26.32175)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 70.30279167,  25.7765)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 69.896625,  25.69575)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.89745833,  24.13872222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.31875,  22.889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.30983333,  26.23986111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 27.836125,  18.21332222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 27.836125,  18.21332222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 135.21465, -4.71366111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 134.863425, -4.48787222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 195.04046667,  27.38480556)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 34.36804583, -5.20401667)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 34.36804583, -5.20401667)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 21.00090833,  36.40599222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 350.953, -1.13619)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 149.36175,  3.23359444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 149.36175,  3.23359444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 29.99016667,  0.55291389)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 36.32083333, -4.54972222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 42.322125, -4.21447222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 148.03983333,  21.72034444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 148.03983333,  21.72034444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 36.32083333, -4.54972222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 350.953, -1.13619)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 29.99016667,  0.55291389)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 42.322125, -4.21447222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 157.36470833,  61.25147222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 157.36470833,  61.25147222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 34.794125, -5.85413889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 29.13983333,  0.96363889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 28.24441667,  1.08538889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 24.92958333,  6.215)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 16.92570833,  1.00038889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 55.07220833,  0.53127778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 6.61620833, -10.17236111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 43.620125, -0.80969444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 154.75904167,  74.70683333)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 154.75908333,  74.70683333)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 218.67883333,  31.48797222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 188.13845833,  27.12094444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 154.77341667,  46.45391111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 188.13845833,  27.12096944)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 180.71545833,  44.25761111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 114.62345833,  38.78742222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 150.23825,  2.23150833)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 150.55969167,  2.21374167)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 149.89347917,  2.52690278)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 61.18008333,  26.31513889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.13354167,  22.95738889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 67.37533333,  24.66527778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 69.97458333,  26.05305556)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 67.90054167,  18.22866667)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 69.807875,  25.88911111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 64.71445833,  28.34055556)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 67.93516667,  18.14208333)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 73.02783333,  30.78819444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 66.73454167,  24.72647222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 66.98875,  26.32175)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 70.30279167,  25.7765)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 69.896625,  25.69575)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.89745833,  24.13872222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.31875,  22.889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.30983333,  26.23986111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 27.836125,  18.21332222)]>
# ...
#     [( 188.13845833,  27.12094444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 154.77341667,  46.45391111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 188.13845833,  27.12096944)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 180.71545833,  44.25761111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 114.62345833,  38.78742222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 150.23825,  2.23150833)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 150.55969167,  2.21374167)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 149.89347917,  2.52690278)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 61.18008333,  26.31513889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.13354167,  22.95738889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 67.37533333,  24.66527778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 69.97458333,  26.05305556)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 67.90054167,  18.22866667)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 69.807875,  25.88911111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 64.71445833,  28.34055556)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 67.93516667,  18.14208333)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 73.02783333,  30.78819444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 66.73454167,  24.72647222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 66.98875,  26.32175)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 70.30279167,  25.7765)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 69.896625,  25.69575)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.89745833,  24.13872222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.31875,  22.889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.30983333,  26.23986111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 27.836125,  18.21332222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 27.836125,  18.21332222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 135.21465, -4.71366111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 134.863425, -4.48787222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 195.04046667,  27.38480556)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 34.36804583, -5.20401667)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 34.36804583, -5.20401667)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 21.00090833,  36.40599222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 350.953, -1.13619)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 149.36175,  3.23359444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 149.36175,  3.23359444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 29.99016667,  0.55291389)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 36.32083333, -4.54972222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 42.322125, -4.21447222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 148.03983333,  21.72034444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 148.03983333,  21.72034444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 36.32083333, -4.54972222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 350.953, -1.13619)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 29.99016667,  0.55291389)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 42.322125, -4.21447222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 157.36470833,  61.25147222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 157.36470833,  61.25147222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 34.794125, -5.85413889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 29.13983333,  0.96363889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 28.24441667,  1.08538889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 24.92958333,  6.215)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 16.92570833,  1.00038889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 55.07220833,  0.53127778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 6.61620833, -10.17236111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 43.620125, -0.80969444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 154.75904167,  74.70683333)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 154.75908333,  74.70683333)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 218.67883333,  31.48797222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 188.13845833,  27.12094444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 154.77341667,  46.45391111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 188.13845833,  27.12096944)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 180.71545833,  44.25761111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 114.62345833,  38.78742222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 150.23825,  2.23150833)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 150.55969167,  2.21374167)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 149.89347917,  2.52690278)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 61.18008333,  26.31513889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.13354167,  22.95738889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 67.37533333,  24.66527778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 69.97458333,  26.05305556)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 67.90054167,  18.22866667)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 69.807875,  25.88911111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 64.71445833,  28.34055556)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 67.93516667,  18.14208333)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 73.02783333,  30.78819444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 66.73454167,  24.72647222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 66.98875,  26.32175)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 70.30279167,  25.7765)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 69.896625,  25.69575)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.89745833,  24.13872222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.31875,  22.889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.30983333,  26.23986111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 27.836125,  18.21332222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 27.836125,  18.21332222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 135.21465, -4.71366111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 134.863425, -4.48787222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 195.04046667,  27.38480556)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 34.36804583, -5.20401667)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 34.36804583, -5.20401667)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 21.00090833,  36.40599222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 350.953, -1.13619)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 149.36175,  3.23359444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 149.36175,  3.23359444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 29.99016667,  0.55291389)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 36.32083333, -4.54972222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 42.322125, -4.21447222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 148.03983333,  21.72034444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 148.03983333,  21.72034444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 36.32083333, -4.54972222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 350.953, -1.13619)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 29.99016667,  0.55291389)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 42.322125, -4.21447222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 157.36470833,  61.25147222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 157.36470833,  61.25147222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 34.794125, -5.85413889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 29.13983333,  0.96363889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 28.24441667,  1.08538889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 24.92958333,  6.215)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 16.92570833,  1.00038889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 55.07220833,  0.53127778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 6.61620833, -10.17236111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 43.620125, -0.80969444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 154.75904167,  74.70683333)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 154.75908333,  74.70683333)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 20.39733333,  3.29462778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 218.67883333,  31.48797222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 188.13845833,  27.12094444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 154.77341667,  46.45391111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 41.10758333,  19.1785)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 188.13845833,  27.12096944)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 323.81358333, -6.97452778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 180.71545833,  44.25761111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 114.62345833,  38.78742222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 150.23825,  2.23150833)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 150.55969167,  2.21374167)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 149.89347917,  2.52690278)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 61.18008333,  26.31513889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.13354167,  22.95738889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 67.37533333,  24.66527778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 69.97458333,  26.05305556)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 67.90054167,  18.22866667)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 69.807875,  25.88911111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 64.71445833,  28.34055556)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 67.93516667,  18.14208333)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 73.02783333,  30.78819444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 66.73454167,  24.72647222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 66.98875,  26.32175)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 70.30279167,  25.7765)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 69.896625,  25.69575)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.89745833,  24.13872222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.31875,  22.889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 68.30983333,  26.23986111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 27.836125,  18.21332222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 27.836125,  18.21332222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 135.21465, -4.71366111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 134.863425, -4.48787222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 195.04046667,  27.38480556)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 34.36804583, -5.20401667)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 34.36804583, -5.20401667)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 21.00090833,  36.40599222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 350.953, -1.13619)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 149.36175,  3.23359444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 149.36175,  3.23359444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 29.99016667,  0.55291389)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 36.32083333, -4.54972222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 42.322125, -4.21447222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 148.03983333,  21.72034444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 148.03983333,  21.72034444)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 36.32083333, -4.54972222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 350.953, -1.13619)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 29.99016667,  0.55291389)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 42.322125, -4.21447222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 157.36470833,  61.25147222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 157.36470833,  61.25147222)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 34.794125, -5.85413889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 29.13983333,  0.96363889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 28.24441667,  1.08538889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 24.92958333,  6.215)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 16.92570833,  1.00038889)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 55.07220833,  0.53127778)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 6.61620833, -10.17236111)]>
# target:  <SkyCoord (ICRS): (ra, dec) in deg
#     [( 43.620125, -0.80969444)]>

# %%
constraints.append(AirmassConstraint(max=2.0))

# %%
if False:
    is_event_observable(constraints, mmto, targets, times)

# %%
constraints.append(AtNightConstraint(max_solar_altitude=-12 * u.deg))

# %%
if False:
    is_event_observable(constraints, mmto, targets, times)
